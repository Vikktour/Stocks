# %% [markdown]
# # Green and Red Candle Project
# ## Coded by Victor Zheng & Supervised under Mohammed Hasan

# %% [raw]
# ## Progress
# # 04-17-2021: Debugged last index dateTimeMaxHTP for why it was (0,0,0)
# # 04-18-2021: Worked on getting dateTimeMinLTP - the minimum LTP for a paritcular row in dateTimeMaxHTP
# # 04-19-2021A: Debugged maxHTPTime == "9:37:00 AM": case - it doesn't select the minLTP after maxtime, it selects the LTP at 9:37AM
# # 04-19-2021B: For each date, found the dropPerc and map it to number of occurrence and found highest occurrence to find buyPriceGeneral. Then found the profitPerc and mapped it to number of occurences and found highest occurrence to know what protit % we will accept to limit sell at
# # 04-20-2021: Added margins for % change from OTP to minLTP. Merged previous code using datasetToMerged(). Started on profits = [] #(date,profit)
# # 04-21-2021: Worked on profits and netProfit for mostOccurredDropPerc and mostOccuredBuyProfit percents
# # 04-23-2021: Converted some blocks to use nparray instead of df, which helps the code run faster
# # 05-01-2021: Finished changing the df to nparray for faster calculation. Fixed the (0,0,0,0) bug by using enumerate() with startIdx as start
#
# # 05-02-2021: Use the dataset with powershell data to calculate the candle type (closetradeprice - opentradeprice @9:30)
# # removed data with time >= 4:00pm
# # changed df.values to df.to_numpy()
#
# tmr
# #change it so that we only buy 1 time each day

# %% [raw]
# Features to try:
# 1) If Volume > 2M then no longer consider buying
# 2) Relatives strength index (RSI)
# 3) Moving Average Convergence Divergence (MACD)
#
# 4) Count of the key words (e.g. name of stock, company, etc) #appearance in Google, Twitter, Reddit WSB

# %%
"""
import time
tic = time.perf_counter()
npData = df.values
toc = time.perf_counter()
print(f"time to use .values is: {toc-tic:0.4f} seconds") #0.1871 seconds
"""
"""
#we learned that using df.iterrows to convert to lise using append is a lot slower than using df.values
npList = []
tic = time.perf_counter()
for index,row in df.iterrows():
    npList.append(row)
toc = time.perf_counter()
print(f"time to use append is: {toc-tic:0.4f} seconds") #18.4474 seconds
"""
"""
npList = [None] * len(df)
tic = time.perf_counter()
for index,row in df.iterrows():
    npList.append(row)
toc = time.perf_counter()
print(f"time to use initialized with setting is: {toc-tic:0.4f} seconds") #18.3087 seconds
"""
# Out:
# '\nnpList = [None] * len(df)\ntic = time.perf_counter()\nfor index,row in df.iterrows():\n    npList.append(row)\ntoc = time.perf_counter()\nprint(f"time to use initialized with setting is: {toc-tic:0.4f} seconds") #18.3087 seconds\n'

# %% [markdown]
# ## Get minimum value for call/put between 9:46AM and the timecallmax for that day

# %%
#function that compares if time 1 is < time 2
def beforeTime(time1,time2):
    
    if len(time1) != 11:
        time1 = "0" + time1
    if len(time2) != 11:
        time2 = "0" + time2
    
    #check last 2 chars to see if AM or PM
    if time1[-2:] == "AM":
        t1IsAM = True
    else:
        t1IsAM = False
    if time2[-2:] == "AM":
        t2IsAM = True
    else:
        t2IsAM = False
    
    if t1IsAM and not t2IsAM:
        return True
    elif t1IsAM and t2IsAM:
        return True if time1 < time2 else False
    elif not t1IsAM and t2IsAM:
        return False
    else: #t1 is pm and t2 is pm
        return True if time1 < time2 else False

#sample test cases - expected TFFF
print(beforeTime("10:05:00 AM","3:59:00 PM"), beforeTime("10:05:00 PM","3:59:00 PM"), beforeTime("10:05:00 AM","3:59:00 AM"),beforeTime("10:05:00 PM","3:59:00 AM"))

def afterTime(time1,time2):
    if time1 == time2:
        return False
    return not beforeTime(time1,time2)
# Out:
# True False False False

# %%
import pandas as pd
import numpy as np
import math
#df = pd.read_csv('Jan 2020 - Dec 2020 merged SPY - Copy.csv')
df = pd.read_csv('Jan 2020 - Dec 2020 merged SPY.csv')
#df = pd.read_csv('Even-smaller-dataframe.csv')

npData = df.to_numpy()
#Remove 4:00PM rows from the dataset
dataWithoutAfter4 = []
for row in npData:
    if beforeTime(row[1],"4:00:00 PM"):
        dataWithoutAfter4.append(row)
npData = dataWithoutAfter4
        
N = len(df)

#40% training
#30% validation
#30% cross-validation
#trainingSlice = int(0.4*N)
#validationSlice = int(0.7*N)
#crossValidationSlice = N

#50% training
#50% validation
trainingSlice = int(0.5*N)
validationSlice = N

trainingSet = npData[0:trainingSlice]
validationSet = npData[trainingSlice:validationSlice]
#crossValidationSet = npData[validationSlice:crossValidationSlice]

# %%
df
# Out:
#             Date TimeBarStart Ticker CallPut  Strike  ExpirationDate  \
# 0       20200103   9:30:00 AM    SPY       P   320.5        20200103
# 1       20200103   9:30:00 AM    SPY       P   305.0        20200103
# 2       20200103   9:30:00 AM    SPY       P   317.0        20200103
# 3       20200103   9:30:00 AM    SPY       P   313.0        20200103
# 4       20200103   9:30:00 AM    SPY       P   321.5        20200103
# ...          ...          ...    ...     ...     ...             ...
# 300055  20200311   4:14:00 PM    SPY       C   274.0        20200311
# 300056  20200311   4:14:00 PM    SPY       C   271.0        20200311
# 300057  20200311   4:14:00 PM    SPY       C   276.0        20200311
# 300058  20200311   4:14:00 PM    SPY       C   282.0        20200311
# 300059  20200311   4:14:00 PM    SPY       C   280.0        20200311
#
#         OpenTradePrice  HighTradePrice  LowTradePrice  CloseTradePrice  \
# 0                 0.57            0.60           0.47             0.47
# 1                 0.01            0.01           0.01             0.01
# 2                 0.12            0.12           0.10             0.10
# 3                 0.02            0.02           0.02             0.02
# 4                 0.98            0.98           0.82             0.82
# ...                ...             ...            ...              ...
# 300055            1.06            1.11           1.02             1.05
# 300056            3.75            3.75           3.75             3.75
# 300057            0.27            0.28           0.17             0.25
# 300058            0.01            0.01           0.01             0.01
# 300059            0.02            0.02           0.02             0.02
#
#         UnderOpenBidPrice  UnderOpenAskPrice  UnderCloseBidPrice  \
# 0                  321.13             321.15              321.55
# 1                  321.13             321.16              321.13
# 2                  321.18             321.20              321.33
# 3                  321.44             321.45              321.44
# 4                  321.14             321.16              321.47
# ...                   ...                ...                 ...
# 300055             274.65             274.71              274.62
# 300056             274.67             274.71              274.67
# 300057             274.70             274.74              274.59
# 300058             274.54             274.59              274.54
# 300059             274.58             274.64              274.58
#
#         UnderCloseAskPrice    VWAP  Volume  TotalTrades
# 0                   321.56  0.5865     241           17
# 1                   321.16  0.0100       6            1
# 2                   321.34  0.1018      11            2
# 3                   321.45  0.0200       1            1
# 4                   321.48  0.9241     279           43
# ...                    ...     ...     ...          ...
# 300055              274.68  1.0830      23            7
# 300056              274.71  3.7500       1            1
# 300057              274.60  0.2406      17            8
# 300058              274.59  0.0100       3            2
# 300059              274.64  0.0200     100            1
#
# [300060 rows x 17 columns]

# %%
import os
os.getcwd()
#here1
# Out:
# 'C:\\Users\\Victor\\Desktop\\0-Leetcode\\Desktop\\Projects\\CandleAnalysis'

# %% [markdown]
# ### Use the dataset with powershell data to calculate the candle type (closetradeprice - opentradeprice @9:30)

# %%
import os
directory = r"C:\Users\Victor\Desktop\0-Leetcode\Desktop\Projects\CandleAnalysis\Spy-Powershell"

dateToCandle = {} #maps date to candleType

for filename in os.listdir(directory):
    if filename.endswith(".csv"): 
        #print(os.path.join(directory, filename))
        df1 = pd.read_csv(os.path.join(directory, filename))
        numDf1 = df1.to_numpy()
        for row in numDf1:
            #print(row)
            dateTime = row[1].split(" ")
            time = dateTime[1]
            if time == "9:30":
                candleType = "GREEN" if row[5] - row[2] >= 0 else "RED"
                #convert date to yyyymmdd
                date = dateTime[0]
                date = date.split("/")
                year = date[2]
                month = date[0]
                day = date[1]
                if len(month) == 1:
                    month = "0" + month
                if len(day) == 1:
                    day = "0" + day
                date = int(year + month + day)
                dateToCandle[date] = candleType

# %%
for date in dateToCandle:
    print("date={},candle={}".format(date,dateToCandle[date]))
# Out:
# date=20160218,candle=RED
# date=20160219,candle=GREEN
# date=20160222,candle=GREEN
# date=20160223,candle=RED
# date=20160224,candle=RED
# date=20160225,candle=GREEN
# date=20160226,candle=RED
# date=20160229,candle=RED
# date=20160301,candle=RED
# date=20160302,candle=RED
# date=20160303,candle=RED
# date=20160304,candle=RED
# date=20160307,candle=GREEN
# date=20160308,candle=RED
# date=20160309,candle=RED
# date=20160310,candle=GREEN
# date=20160311,candle=GREEN
# date=20160314,candle=GREEN
# date=20160315,candle=RED
# date=20160316,candle=GREEN
# date=20160317,candle=GREEN
# date=20160318,candle=RED
# date=20160321,candle=GREEN
# date=20160322,candle=GREEN
# date=20160323,candle=RED
# date=20160324,candle=RED
# date=20160328,candle=RED
# date=20160329,candle=RED
# date=20160330,candle=RED
# date=20160331,candle=GREEN
# date=20160401,candle=RED
# date=20160404,candle=RED
# date=20160405,candle=GREEN
# date=20160406,candle=GREEN
# date=20160407,candle=GREEN
# date=20160408,candle=RED
# date=20160411,candle=RED
# date=20160412,candle=RED
# date=20160413,candle=GREEN
# date=20160414,candle=RED
# date=20160415,candle=RED
# date=20160418,candle=GREEN
# date=20160419,candle=RED
# date=20160420,candle=RED
# date=20160421,candle=GREEN
# date=20160422,candle=GREEN
# date=20160425,candle=GREEN
# date=20160426,candle=RED
# date=20160427,candle=GREEN
# date=20160428,candle=RED
# date=20160429,candle=GREEN
# date=20160502,candle=RED
# date=20160503,candle=RED
# date=20160504,candle=GREEN
# date=20160505,candle=GREEN
# date=20160506,candle=GREEN
# date=20160509,candle=GREEN
# date=20160510,candle=GREEN
# date=20160511,candle=GREEN
# date=20160512,candle=GREEN
# date=20160513,candle=GREEN
# date=20160516,candle=GREEN
# date=20160517,candle=GREEN
# date=20160518,candle=RED
# date=20160519,candle=GREEN
# date=20160520,candle=GREEN
# date=20160523,candle=GREEN
# date=20160524,candle=GREEN
# date=20160525,candle=GREEN
# date=20160526,candle=GREEN
# date=20160527,candle=GREEN
# date=20160531,candle=RED
# date=20160601,candle=RED
# date=20160602,candle=RED
# date=20160603,candle=RED
# date=20160606,candle=RED
# date=20160607,candle=GREEN
# date=20160608,candle=GREEN
# date=20160609,candle=RED
# date=20160610,candle=GREEN
# date=20160613,candle=GREEN
# date=20160614,candle=GREEN
# date=20160615,candle=RED
# date=20160616,candle=RED
# date=20160617,candle=RED
# date=20160620,candle=GREEN
# date=20160621,candle=RED
# date=20160622,candle=GREEN
# date=20160623,candle=RED
# date=20160624,candle=GREEN
# date=20160627,candle=RED
# date=20160628,candle=GREEN
# date=20160629,candle=GREEN
# date=20160630,candle=RED
# date=20160701,candle=GREEN
# date=20160705,candle=RED
# date=20160706,candle=RED
# date=20160707,candle=GREEN
# date=20160708,candle=RED
# date=20160711,candle=GREEN
# date=20160712,candle=GREEN
# date=20160713,candle=RED
# date=20160714,candle=GREEN
# date=20160715,candle=RED
# date=20160718,candle=RED
# date=20160719,candle=GREEN
# date=20160720,candle=RED
# date=20160721,candle=RED
# date=20160722,candle=RED
# date=20160725,candle=RED
# date=20160726,candle=GREEN
# date=20160727,candle=RED
# date=20160728,candle=GREEN
# date=20160729,candle=GREEN
# date=20160801,candle=RED
# date=20160802,candle=GREEN
# date=20160803,candle=RED
# date=20160804,candle=GREEN
# date=20160805,candle=GREEN
# date=20160808,candle=GREEN
# date=20160809,candle=GREEN
# date=20160810,candle=RED
# date=20160811,candle=GREEN
# date=20160812,candle=GREEN
# date=20160815,candle=GREEN
# date=20160816,candle=RED
# date=20160817,candle=RED
# date=20160818,candle=GREEN
# date=20160819,candle=RED
# date=20160822,candle=RED
# date=20160823,candle=GREEN
# date=20160824,candle=RED
# date=20160825,candle=RED
# date=20160826,candle=GREEN
# date=20160829,candle=GREEN
# date=20160830,candle=GREEN
# date=20160831,candle=RED
# date=20160901,candle=GREEN
# date=20160902,candle=GREEN
# date=20160906,candle=RED
# date=20160907,candle=RED
# date=20160908,candle=GREEN
# date=20160909,candle=RED
# date=20160912,candle=GREEN
# date=20160913,candle=RED
# date=20160914,candle=GREEN
# date=20160915,candle=GREEN
# date=20160916,candle=RED
# date=20160919,candle=GREEN
# date=20160920,candle=GREEN
# date=20160921,candle=GREEN
# date=20160922,candle=GREEN
# date=20160923,candle=GREEN
# date=20160926,candle=RED
# date=20160927,candle=RED
# date=20160928,candle=GREEN
# date=20160929,candle=RED
# date=20160930,candle=GREEN
# date=20161003,candle=RED
# date=20161004,candle=GREEN
# date=20161005,candle=GREEN
# date=20161006,candle=RED
# date=20161007,candle=RED
# date=20161010,candle=GREEN
# date=20161011,candle=RED
# date=20161012,candle=RED
# date=20161013,candle=GREEN
# date=20161014,candle=RED
# date=20161017,candle=GREEN
# date=20161018,candle=RED
# date=20161019,candle=RED
# date=20161020,candle=GREEN
# date=20161021,candle=GREEN
# date=20161024,candle=GREEN
# date=20161025,candle=RED
# date=20161026,candle=RED
# date=20161027,candle=RED
# date=20161028,candle=RED
# date=20161031,candle=RED
# date=20161101,candle=RED
# date=20161102,candle=RED
# date=20161103,candle=RED
# date=20161104,candle=RED
# date=20161107,candle=RED
# date=20161108,candle=RED
# date=20161109,candle=GREEN
# date=20161110,candle=GREEN
# date=20161111,candle=RED
# date=20161114,candle=RED
# date=20161115,candle=RED
# date=20161116,candle=GREEN
# date=20161117,candle=GREEN
# date=20161118,candle=GREEN
# date=20161121,candle=GREEN
# date=20161122,candle=GREEN
# date=20161123,candle=GREEN
# date=20161125,candle=RED
# date=20161128,candle=GREEN
# date=20161129,candle=GREEN
# date=20161130,candle=RED
# date=20161201,candle=RED
# date=20161202,candle=RED
# date=20161205,candle=RED
# date=20161206,candle=RED
# date=20161207,candle=GREEN
# date=20161208,candle=GREEN
# date=20161209,candle=GREEN
# date=20161212,candle=RED
# date=20161213,candle=GREEN
# date=20161214,candle=GREEN
# date=20161215,candle=GREEN
# date=20161216,candle=RED
# date=20161219,candle=RED
# date=20161220,candle=GREEN
# date=20161221,candle=GREEN
# date=20161222,candle=RED
# date=20161223,candle=GREEN
# date=20161227,candle=GREEN
# date=20161228,candle=RED
# date=20161229,candle=GREEN
# date=20161230,candle=RED
# date=20170103,candle=GREEN
# date=20170104,candle=GREEN
# date=20170105,candle=GREEN
# date=20170106,candle=RED
# date=20170109,candle=RED
# date=20170110,candle=RED
# date=20170111,candle=GREEN
# date=20170112,candle=RED
# date=20170113,candle=GREEN
# date=20170117,candle=GREEN
# date=20170118,candle=RED
# date=20170119,candle=GREEN
# date=20170120,candle=GREEN
# date=20170123,candle=GREEN
# date=20170124,candle=GREEN
# date=20170125,candle=RED
# date=20170126,candle=GREEN
# date=20170127,candle=RED
# date=20170130,candle=RED
# date=20170131,candle=GREEN
# date=20170201,candle=GREEN
# date=20170202,candle=RED
# date=20170203,candle=RED
# date=20170206,candle=GREEN
# date=20170207,candle=RED
# date=20170208,candle=RED
# date=20170209,candle=GREEN
# date=20170210,candle=GREEN
# date=20170213,candle=GREEN
# date=20170214,candle=GREEN
# date=20170215,candle=GREEN
# date=20170216,candle=GREEN
# date=20170217,candle=GREEN
# date=20170221,candle=GREEN
# date=20170222,candle=GREEN
# date=20170223,candle=RED
# date=20170224,candle=RED
# date=20170227,candle=RED
# date=20170228,candle=GREEN
# date=20170301,candle=GREEN
# date=20170302,candle=RED
# date=20170303,candle=GREEN
# date=20170306,candle=RED
# date=20170307,candle=GREEN
# date=20170308,candle=RED
# date=20170309,candle=RED
# date=20170310,candle=RED
# date=20170313,candle=GREEN
# date=20170314,candle=RED
# date=20170315,candle=RED
# date=20170316,candle=GREEN
# date=20170317,candle=RED
# date=20170320,candle=RED
# date=20170321,candle=GREEN
# date=20170322,candle=RED
# date=20170323,candle=RED
# date=20170324,candle=GREEN
# date=20170327,candle=GREEN
# date=20170328,candle=GREEN
# date=20170329,candle=RED
# date=20170330,candle=RED
# date=20170331,candle=RED
# date=20170403,candle=GREEN
# date=20170404,candle=RED
# date=20170405,candle=RED
# date=20170406,candle=RED
# date=20170407,candle=RED
# date=20170410,candle=GREEN
# date=20170411,candle=GREEN
# date=20170412,candle=RED
# date=20170413,candle=GREEN
# date=20170417,candle=GREEN
# date=20170418,candle=GREEN
# date=20170419,candle=GREEN
# date=20170420,candle=GREEN
# date=20170421,candle=RED
# date=20170424,candle=RED
# date=20170425,candle=GREEN
# date=20170426,candle=GREEN
# date=20170427,candle=RED
# date=20170428,candle=RED
# date=20170501,candle=RED
# date=20170502,candle=GREEN
# date=20170503,candle=RED
# date=20170504,candle=RED
# date=20170505,candle=RED
# date=20170508,candle=GREEN
# date=20170509,candle=GREEN
# date=20170510,candle=RED
# date=20170511,candle=GREEN
# date=20170512,candle=RED
# date=20170515,candle=GREEN
# date=20170516,candle=RED
# date=20170517,candle=GREEN
# date=20170518,candle=GREEN
# date=20170519,candle=GREEN
# date=20170522,candle=GREEN
# date=20170523,candle=RED
# date=20170524,candle=RED
# date=20170525,candle=RED
# date=20170526,candle=GREEN
# date=20170530,candle=RED
# date=20170531,candle=RED
# date=20170601,candle=RED
# date=20170602,candle=GREEN
# date=20170605,candle=RED
# date=20170606,candle=RED
# date=20170607,candle=RED
# date=20170608,candle=RED
# date=20170609,candle=GREEN
# date=20170612,candle=GREEN
# date=20170613,candle=GREEN
# date=20170614,candle=RED
# date=20170615,candle=GREEN
# date=20170616,candle=RED
# date=20170619,candle=RED
# date=20170620,candle=RED
# date=20170621,candle=RED
# date=20170622,candle=RED
# date=20170623,candle=RED
# date=20170626,candle=GREEN
# date=20170627,candle=RED
# date=20170628,candle=GREEN
# date=20170629,candle=RED
# date=20170630,candle=GREEN
# date=20170703,candle=GREEN
# date=20170705,candle=RED
# date=20170706,candle=GREEN
# date=20170707,candle=GREEN
# date=20170710,candle=GREEN
# date=20170711,candle=RED
# date=20170712,candle=GREEN
# date=20170713,candle=GREEN
# date=20170714,candle=GREEN
# date=20170717,candle=GREEN
# date=20170718,candle=RED
# date=20170719,candle=GREEN
# date=20170720,candle=RED
# date=20170721,candle=GREEN
# date=20170724,candle=GREEN
# date=20170725,candle=RED
# date=20170726,candle=RED
# date=20170727,candle=RED
# date=20170728,candle=RED
# date=20170731,candle=GREEN
# date=20170801,candle=RED
# date=20170802,candle=RED
# date=20170803,candle=RED
# date=20170804,candle=RED
# date=20170807,candle=RED
# date=20170808,candle=GREEN
# date=20170809,candle=GREEN
# date=20170810,candle=GREEN
# date=20170811,candle=GREEN
# date=20170814,candle=GREEN
# date=20170815,candle=RED
# date=20170816,candle=GREEN
# date=20170817,candle=GREEN
# date=20170818,candle=RED
# date=20170821,candle=RED
# date=20170822,candle=GREEN
# date=20170823,candle=GREEN
# date=20170824,candle=GREEN
# date=20170825,candle=GREEN
# date=20170828,candle=RED
# date=20170829,candle=GREEN
# date=20170830,candle=RED
# date=20170831,candle=GREEN
# date=20170901,candle=GREEN
# date=20170905,candle=GREEN
# date=20170906,candle=RED
# date=20170907,candle=RED
# date=20170908,candle=RED
# date=20170911,candle=GREEN
# date=20170912,candle=GREEN
# date=20170913,candle=GREEN
# date=20170914,candle=RED
# date=20170915,candle=GREEN
# date=20170918,candle=RED
# date=20170919,candle=RED
# date=20170920,candle=RED
# date=20170921,candle=GREEN
# date=20170922,candle=GREEN
# date=20170925,candle=GREEN
# date=20170926,candle=GREEN
# date=20170927,candle=GREEN
# date=20170928,candle=GREEN
# date=20170929,candle=GREEN
# date=20171002,candle=RED
# date=20171003,candle=RED
# date=20171004,candle=GREEN
# date=20171005,candle=GREEN
# date=20171006,candle=RED
# date=20171009,candle=GREEN
# date=20171010,candle=RED
# date=20171011,candle=GREEN
# date=20171012,candle=GREEN
# date=20171013,candle=RED
# date=20171016,candle=GREEN
# date=20171017,candle=RED
# date=20171018,candle=RED
# date=20171019,candle=GREEN
# date=20171020,candle=RED
# date=20171023,candle=RED
# date=20171024,candle=GREEN
# date=20171025,candle=GREEN
# date=20171026,candle=GREEN
# date=20171027,candle=GREEN
# date=20171030,candle=GREEN
# date=20171031,candle=RED
# date=20171101,candle=GREEN
# date=20171102,candle=GREEN
# date=20171103,candle=RED
# date=20171106,candle=GREEN
# date=20171107,candle=GREEN
# date=20171108,candle=RED
# date=20171109,candle=GREEN
# date=20171110,candle=GREEN
# date=20171113,candle=GREEN
# date=20171114,candle=GREEN
# date=20171115,candle=RED
# date=20171116,candle=GREEN
# date=20171117,candle=RED
# date=20171120,candle=RED
# date=20171121,candle=GREEN
# date=20171122,candle=GREEN
# date=20171124,candle=RED
# date=20171127,candle=RED
# date=20171128,candle=GREEN
# date=20171129,candle=RED
# date=20171130,candle=GREEN
# date=20171201,candle=GREEN
# date=20171204,candle=RED
# date=20171205,candle=RED
# date=20171206,candle=GREEN
# date=20171207,candle=GREEN
# date=20171208,candle=GREEN
# date=20171211,candle=GREEN
# date=20171212,candle=RED
# date=20171213,candle=GREEN
# date=20171214,candle=GREEN
# date=20171215,candle=GREEN
# date=20171218,candle=GREEN
# date=20171219,candle=RED
# date=20171220,candle=RED
# date=20171221,candle=RED
# date=20171222,candle=RED
# date=20171226,candle=GREEN
# date=20171227,candle=RED
# date=20171228,candle=RED
# date=20171229,candle=RED
# date=20180102,candle=RED
# date=20180103,candle=GREEN
# date=20180104,candle=GREEN
# date=20180105,candle=RED
# date=20180108,candle=GREEN
# date=20180109,candle=GREEN
# date=20180110,candle=GREEN
# date=20180111,candle=RED
# date=20180112,candle=GREEN
# date=20180116,candle=GREEN
# date=20180117,candle=RED
# date=20180118,candle=RED
# date=20180119,candle=RED
# date=20180122,candle=GREEN
# date=20180123,candle=GREEN
# date=20180124,candle=GREEN
# date=20180125,candle=RED
# date=20180126,candle=RED
# date=20180129,candle=RED
# date=20180130,candle=GREEN
# date=20180131,candle=GREEN
# date=20180201,candle=GREEN
# date=20180202,candle=RED
# date=20180205,candle=GREEN
# date=20180206,candle=GREEN
# date=20180207,candle=GREEN
# date=20180208,candle=RED
# date=20180209,candle=RED
# date=20180212,candle=GREEN
# date=20180213,candle=GREEN
# date=20180214,candle=GREEN
# date=20180215,candle=RED
# date=20180216,candle=GREEN
# date=20180220,candle=GREEN
# date=20180221,candle=GREEN
# date=20180222,candle=GREEN
# date=20180223,candle=GREEN
# date=20180226,candle=GREEN
# date=20180227,candle=RED
# date=20180228,candle=RED
# date=20180301,candle=GREEN
# date=20180302,candle=GREEN
# date=20180305,candle=GREEN
# date=20180306,candle=RED
# date=20180307,candle=GREEN
# date=20180308,candle=GREEN
# date=20180309,candle=RED
# date=20180312,candle=GREEN
# date=20180313,candle=RED
# date=20180314,candle=RED
# date=20180315,candle=RED
# date=20180316,candle=GREEN
# date=20180319,candle=RED
# date=20180320,candle=GREEN
# date=20180321,candle=RED
# date=20180322,candle=RED
# date=20180323,candle=GREEN
# date=20180326,candle=GREEN
# date=20180327,candle=RED
# date=20180328,candle=GREEN
# date=20180329,candle=GREEN
# date=20180402,candle=GREEN
# date=20180403,candle=RED
# date=20180404,candle=GREEN
# date=20180405,candle=GREEN
# date=20180406,candle=GREEN
# date=20180409,candle=GREEN
# date=20180410,candle=RED
# date=20180411,candle=GREEN
# date=20180412,candle=GREEN
# date=20180413,candle=RED
# date=20180416,candle=RED
# date=20180417,candle=RED
# date=20180418,candle=GREEN
# date=20180419,candle=RED
# date=20180420,candle=RED
# date=20180423,candle=RED
# date=20180424,candle=RED
# date=20180425,candle=RED
# date=20180426,candle=RED
# date=20180427,candle=GREEN
# date=20180430,candle=GREEN
# date=20180501,candle=RED
# date=20180502,candle=RED
# date=20180503,candle=RED
# date=20180504,candle=RED
# date=20180507,candle=GREEN
# date=20180508,candle=GREEN
# date=20180509,candle=GREEN
# date=20180510,candle=RED
# date=20180511,candle=GREEN
# date=20180514,candle=GREEN
# date=20180515,candle=RED
# date=20180516,candle=GREEN
# date=20180517,candle=RED
# date=20180518,candle=RED
# date=20180521,candle=GREEN
# date=20180522,candle=GREEN
# date=20180523,candle=GREEN
# date=20180524,candle=GREEN
# date=20180525,candle=RED
# date=20180529,candle=RED
# date=20180530,candle=GREEN
# date=20180531,candle=RED
# date=20180601,candle=GREEN
# date=20180604,candle=GREEN
# date=20180605,candle=RED
# date=20180606,candle=RED
# date=20180607,candle=RED
# date=20180608,candle=RED
# date=20180611,candle=GREEN
# date=20180612,candle=GREEN
# date=20180613,candle=RED
# date=20180614,candle=RED
# date=20180615,candle=RED
# date=20180618,candle=RED
# date=20180619,candle=GREEN
# date=20180620,candle=GREEN
# date=20180621,candle=RED
# date=20180622,candle=RED
# date=20180625,candle=GREEN
# date=20180626,candle=RED
# date=20180627,candle=GREEN
# date=20180628,candle=GREEN
# date=20180629,candle=GREEN
# date=20180702,candle=GREEN
# date=20180703,candle=RED
# date=20180705,candle=RED
# date=20180706,candle=RED
# date=20180709,candle=GREEN
# date=20180710,candle=RED
# date=20180711,candle=GREEN
# date=20180712,candle=RED
# date=20180713,candle=GREEN
# date=20180716,candle=GREEN
# date=20180717,candle=GREEN
# date=20180718,candle=GREEN
# date=20180719,candle=GREEN
# date=20180720,candle=RED
# date=20180723,candle=RED
# date=20180724,candle=GREEN
# date=20180725,candle=GREEN
# date=20180726,candle=GREEN
# date=20180727,candle=RED
# date=20180730,candle=RED
# date=20180731,candle=GREEN
# date=20180801,candle=GREEN
# date=20180802,candle=GREEN
# date=20180803,candle=GREEN
# date=20180806,candle=RED
# date=20180807,candle=GREEN
# date=20180808,candle=RED
# date=20180809,candle=GREEN
# date=20180810,candle=GREEN
# date=20180813,candle=GREEN
# date=20180814,candle=GREEN
# date=20180815,candle=RED
# date=20180816,candle=GREEN
# date=20180817,candle=RED
# date=20180820,candle=GREEN
# date=20180821,candle=GREEN
# date=20180822,candle=GREEN
# date=20180823,candle=GREEN
# date=20180824,candle=GREEN
# date=20180827,candle=GREEN
# date=20180828,candle=GREEN
# date=20180829,candle=RED
# date=20180830,candle=GREEN
# date=20180831,candle=GREEN
# date=20180904,candle=RED
# date=20180905,candle=RED
# date=20180906,candle=RED
# date=20180907,candle=GREEN
# date=20180910,candle=RED
# date=20180911,candle=RED
# date=20180912,candle=GREEN
# date=20180913,candle=GREEN
# date=20180914,candle=RED
# date=20180917,candle=RED
# date=20180918,candle=GREEN
# date=20180919,candle=GREEN
# date=20180920,candle=GREEN
# date=20180921,candle=RED
# date=20180924,candle=RED
# date=20180925,candle=RED
# date=20180926,candle=GREEN
# date=20180927,candle=RED
# date=20180928,candle=GREEN
# date=20181001,candle=GREEN
# date=20181002,candle=GREEN
# date=20181003,candle=GREEN
# date=20181004,candle=RED
# date=20181005,candle=GREEN
# date=20181008,candle=GREEN
# date=20181009,candle=GREEN
# date=20181010,candle=RED
# date=20181011,candle=GREEN
# date=20181012,candle=RED
# date=20181015,candle=RED
# date=20181016,candle=RED
# date=20181017,candle=RED
# date=20181018,candle=RED
# date=20181019,candle=GREEN
# date=20181022,candle=GREEN
# date=20181023,candle=GREEN
# date=20181024,candle=GREEN
# date=20181025,candle=RED
# date=20181026,candle=RED
# date=20181029,candle=GREEN
# date=20181030,candle=GREEN
# date=20181031,candle=GREEN
# date=20181101,candle=GREEN
# date=20181102,candle=RED
# date=20181105,candle=GREEN
# date=20181106,candle=GREEN
# date=20181107,candle=GREEN
# date=20181108,candle=GREEN
# date=20181109,candle=RED
# date=20181112,candle=RED
# date=20181113,candle=GREEN
# date=20181114,candle=RED
# date=20181115,candle=RED
# date=20181116,candle=RED
# date=20181119,candle=RED
# date=20181120,candle=GREEN
# date=20181121,candle=GREEN
# date=20181123,candle=GREEN
# date=20181126,candle=GREEN
# date=20181127,candle=GREEN
# date=20181128,candle=RED
# date=20181129,candle=RED
# date=20181130,candle=RED
# date=20181203,candle=RED
# date=20181204,candle=RED
# date=20181206,candle=GREEN
# date=20181207,candle=GREEN
# date=20181210,candle=GREEN
# date=20181211,candle=RED
# date=20181212,candle=RED
# date=20181213,candle=RED
# date=20181214,candle=RED
# date=20181217,candle=RED
# date=20181218,candle=GREEN
# date=20181219,candle=GREEN
# date=20181220,candle=GREEN
# date=20181221,candle=GREEN
# date=20181224,candle=GREEN
# date=20181226,candle=GREEN
# date=20181227,candle=GREEN
# date=20181228,candle=RED
# date=20181231,candle=GREEN
# date=20190102,candle=GREEN
# date=20190103,candle=RED
# date=20190104,candle=RED
# date=20190107,candle=RED
# date=20190108,candle=GREEN
# date=20190109,candle=GREEN
# date=20190110,candle=RED
# date=20190111,candle=GREEN
# date=20190114,candle=RED
# date=20190115,candle=GREEN
# date=20190116,candle=GREEN
# date=20190117,candle=GREEN
# date=20190118,candle=RED
# date=20190122,candle=RED
# date=20190123,candle=GREEN
# date=20190124,candle=RED
# date=20190125,candle=RED
# date=20190128,candle=RED
# date=20190129,candle=GREEN
# date=20190130,candle=RED
# date=20190131,candle=RED
# date=20190201,candle=RED
# date=20190204,candle=RED
# date=20190205,candle=GREEN
# date=20190206,candle=GREEN
# date=20190207,candle=RED
# date=20190208,candle=GREEN
# date=20190211,candle=GREEN
# date=20190212,candle=GREEN
# date=20190213,candle=GREEN
# date=20190214,candle=RED
# date=20190215,candle=RED
# date=20190219,candle=GREEN
# date=20190220,candle=GREEN
# date=20190221,candle=RED
# date=20190222,candle=GREEN
# date=20190225,candle=GREEN
# date=20190226,candle=RED
# date=20190227,candle=GREEN
# date=20190228,candle=RED
# date=20190301,candle=GREEN
# date=20190304,candle=GREEN
# date=20190305,candle=RED
# date=20190306,candle=RED
# date=20190307,candle=RED
# date=20190308,candle=RED
# date=20190311,candle=GREEN
# date=20190312,candle=RED
# date=20190313,candle=GREEN
# date=20190314,candle=RED
# date=20190315,candle=RED
# date=20190318,candle=GREEN
# date=20190319,candle=RED
# date=20190320,candle=RED
# date=20190321,candle=GREEN
# date=20190322,candle=GREEN
# date=20190325,candle=GREEN
# date=20190326,candle=GREEN
# date=20190327,candle=GREEN
# date=20190328,candle=RED
# date=20190329,candle=RED
# date=20190401,candle=GREEN
# date=20190402,candle=RED
# date=20190403,candle=RED
# date=20190404,candle=GREEN
# date=20190405,candle=RED
# date=20190408,candle=RED
# date=20190409,candle=RED
# date=20190410,candle=GREEN
# date=20190411,candle=RED
# date=20190412,candle=RED
# date=20190415,candle=RED
# date=20190416,candle=RED
# date=20190417,candle=RED
# date=20190418,candle=RED
# date=20190422,candle=GREEN
# date=20190423,candle=RED
# date=20190424,candle=RED
# date=20190425,candle=RED
# date=20190426,candle=RED
# date=20190429,candle=GREEN
# date=20190430,candle=RED
# date=20190501,candle=RED
# date=20190502,candle=RED
# date=20190503,candle=GREEN
# date=20190506,candle=GREEN
# date=20190507,candle=GREEN
# date=20190508,candle=RED
# date=20190509,candle=GREEN
# date=20190510,candle=GREEN
# date=20190513,candle=GREEN
# date=20190514,candle=GREEN
# date=20190515,candle=GREEN
# date=20190516,candle=GREEN
# date=20190517,candle=GREEN
# date=20190520,candle=GREEN
# date=20190521,candle=GREEN
# date=20190522,candle=GREEN
# date=20190523,candle=RED
# date=20190524,candle=GREEN
# date=20190528,candle=GREEN
# date=20190529,candle=RED
# date=20190530,candle=GREEN
# date=20190531,candle=RED
# date=20190603,candle=GREEN
# date=20190604,candle=GREEN
# date=20190605,candle=RED
# date=20190606,candle=RED
# date=20190607,candle=GREEN
# date=20190610,candle=GREEN
# date=20190611,candle=GREEN
# date=20190612,candle=RED
# date=20190613,candle=RED
# date=20190614,candle=RED
# date=20190617,candle=RED
# date=20190618,candle=RED
# date=20190619,candle=RED
# date=20190620,candle=RED
# date=20190621,candle=RED
# date=20190624,candle=GREEN
# date=20190625,candle=RED
# date=20190626,candle=GREEN
# date=20190627,candle=GREEN
# date=20190628,candle=GREEN
# date=20190701,candle=GREEN
# date=20190702,candle=RED
# date=20190703,candle=RED
# date=20190705,candle=RED
# date=20190708,candle=RED
# date=20190709,candle=GREEN
# date=20190710,candle=GREEN
# date=20190711,candle=RED
# date=20190712,candle=RED
# date=20190715,candle=RED
# date=20190716,candle=RED
# date=20190717,candle=GREEN
# date=20190718,candle=GREEN
# date=20190719,candle=RED
# date=20190722,candle=GREEN
# date=20190723,candle=RED
# date=20190724,candle=GREEN
# date=20190725,candle=RED
# date=20190726,candle=GREEN
# date=20190729,candle=RED
# date=20190730,candle=RED
# date=20190731,candle=RED
# date=20190801,candle=GREEN
# date=20190802,candle=RED
# date=20190805,candle=RED
# date=20190806,candle=GREEN
# date=20190807,candle=RED
# date=20190808,candle=RED
# date=20190809,candle=GREEN
# date=20190812,candle=RED
# date=20190813,candle=RED
# date=20190814,candle=GREEN
# date=20190815,candle=GREEN
# date=20190816,candle=GREEN
# date=20190819,candle=GREEN
# date=20190820,candle=RED
# date=20190821,candle=RED
# date=20190822,candle=GREEN
# date=20190823,candle=RED
# date=20190826,candle=GREEN
# date=20190827,candle=RED
# date=20190828,candle=RED
# date=20190829,candle=GREEN
# date=20190830,candle=RED
# date=20190903,candle=GREEN
# date=20190904,candle=RED
# date=20190905,candle=GREEN
# date=20190906,candle=RED
# date=20190909,candle=RED
# date=20190910,candle=RED
# date=20190911,candle=RED
# date=20190912,candle=GREEN
# date=20190913,candle=RED
# date=20190916,candle=GREEN
# date=20190917,candle=GREEN
# date=20190918,candle=RED
# date=20190919,candle=GREEN
# date=20190920,candle=GREEN
# date=20190923,candle=RED
# date=20190924,candle=RED
# date=20190925,candle=GREEN
# date=20190926,candle=RED
# date=20190927,candle=RED
# date=20190930,candle=GREEN
# date=20191001,candle=GREEN
# date=20191002,candle=RED
# date=20191003,candle=GREEN
# date=20191004,candle=GREEN
# date=20191007,candle=GREEN
# date=20191008,candle=RED
# date=20191009,candle=RED
# date=20191010,candle=GREEN
# date=20191011,candle=GREEN
# date=20191014,candle=GREEN
# date=20191015,candle=GREEN
# date=20191016,candle=RED
# date=20191017,candle=GREEN
# date=20191018,candle=GREEN
# date=20191021,candle=RED
# date=20191022,candle=GREEN
# date=20191023,candle=GREEN
# date=20191024,candle=RED
# date=20191025,candle=GREEN
# date=20191028,candle=GREEN
# date=20191029,candle=GREEN
# date=20191030,candle=RED
# date=20191031,candle=RED
# date=20191101,candle=RED
# date=20191104,candle=RED
# date=20191105,candle=RED
# date=20191106,candle=RED
# date=20191107,candle=GREEN
# date=20191108,candle=GREEN
# date=20191111,candle=GREEN
# date=20191112,candle=GREEN
# date=20191113,candle=GREEN
# date=20191114,candle=GREEN
# date=20191115,candle=RED
# date=20191118,candle=RED
# date=20191119,candle=RED
# date=20191120,candle=GREEN
# date=20191121,candle=RED
# date=20191122,candle=RED
# date=20191125,candle=GREEN
# date=20191126,candle=RED
# date=20191127,candle=GREEN
# date=20191129,candle=RED
# date=20191202,candle=RED
# date=20191203,candle=RED
# date=20191204,candle=RED
# date=20191205,candle=RED
# date=20191206,candle=GREEN
# date=20191209,candle=GREEN
# date=20191210,candle=RED
# date=20191211,candle=RED
# date=20191212,candle=RED
# date=20191213,candle=RED
# date=20191216,candle=GREEN
# date=20191217,candle=RED
# date=20191218,candle=RED
# date=20191219,candle=GREEN
# date=20191220,candle=GREEN
# date=20191223,candle=RED
# date=20191224,candle=RED
# date=20191226,candle=GREEN
# date=20191227,candle=RED
# date=20191230,candle=RED
# date=20191231,candle=GREEN
# date=20200102,candle=GREEN
# date=20200103,candle=GREEN
# date=20200106,candle=GREEN
# date=20200107,candle=GREEN
# date=20200108,candle=GREEN
# date=20200109,candle=GREEN
# date=20200110,candle=RED
# date=20200113,candle=RED
# date=20200114,candle=GREEN
# date=20200115,candle=GREEN
# date=20200116,candle=GREEN
# date=20200117,candle=RED
# date=20200121,candle=GREEN
# date=20200122,candle=GREEN
# date=20200123,candle=RED
# date=20200124,candle=RED
# date=20200127,candle=GREEN
# date=20200128,candle=RED
# date=20200129,candle=RED
# date=20200130,candle=GREEN
# date=20200131,candle=RED
# date=20200203,candle=GREEN
# date=20200204,candle=RED
# date=20200205,candle=RED
# date=20200206,candle=RED
# date=20200207,candle=RED
# date=20200210,candle=GREEN
# date=20200211,candle=RED
# date=20200212,candle=GREEN
# date=20200213,candle=GREEN
# date=20200214,candle=GREEN
# date=20200218,candle=GREEN
# date=20200219,candle=GREEN
# date=20200220,candle=GREEN
# date=20200221,candle=RED
# date=20200224,candle=GREEN
# date=20200225,candle=RED
# date=20200226,candle=GREEN
# date=20200227,candle=RED
# date=20200228,candle=GREEN
# date=20200302,candle=RED
# date=20200303,candle=RED
# date=20200304,candle=GREEN
# date=20200305,candle=GREEN
# date=20200306,candle=GREEN
# date=20200309,candle=GREEN
# date=20200310,candle=RED
# date=20200311,candle=GREEN
# date=20200312,candle=RED
# date=20200313,candle=RED
# date=20200316,candle=RED
# date=20200317,candle=RED
# date=20200318,candle=GREEN
# date=20200319,candle=RED
# date=20200320,candle=GREEN
# date=20200323,candle=RED
# date=20200324,candle=GREEN
# date=20200325,candle=GREEN
# date=20200326,candle=GREEN
# date=20200327,candle=GREEN
# date=20200330,candle=GREEN
# date=20200331,candle=RED
# date=20200401,candle=GREEN
# date=20200402,candle=GREEN
# date=20200403,candle=GREEN
# date=20200406,candle=RED
# date=20200407,candle=RED
# date=20200408,candle=RED
# date=20200409,candle=RED
# date=20200413,candle=RED
# date=20200414,candle=GREEN
# date=20200415,candle=GREEN
# date=20200416,candle=RED
# date=20200417,candle=RED
# date=20200420,candle=RED
# date=20200421,candle=RED
# date=20200422,candle=RED
# date=20200423,candle=GREEN
# date=20200424,candle=RED
# date=20200427,candle=GREEN
# date=20200428,candle=RED
# date=20200429,candle=RED
# date=20200430,candle=RED
# date=20200501,candle=GREEN
# date=20200504,candle=RED
# date=20200505,candle=GREEN
# date=20200506,candle=GREEN
# date=20200507,candle=GREEN
# date=20200508,candle=RED
# date=20200511,candle=RED
# date=20200512,candle=RED
# date=20200513,candle=RED
# date=20200514,candle=RED
# date=20200515,candle=RED
# date=20200518,candle=GREEN
# date=20200519,candle=RED
# date=20200520,candle=RED
# date=20200521,candle=RED
# date=20200522,candle=RED
# date=20200526,candle=RED
# date=20200527,candle=RED
# date=20200528,candle=RED
# date=20200529,candle=RED
# date=20200601,candle=RED
# date=20200602,candle=RED
# date=20200603,candle=GREEN
# date=20200604,candle=GREEN
# date=20200605,candle=GREEN
# date=20200608,candle=GREEN
# date=20200609,candle=RED
# date=20200610,candle=RED
# date=20200611,candle=RED
# date=20200612,candle=RED
# date=20200615,candle=RED
# date=20200616,candle=RED
# date=20200617,candle=RED
# date=20200618,candle=GREEN
# date=20200619,candle=RED
# date=20200622,candle=RED
# date=20200623,candle=RED
# date=20200624,candle=RED
# date=20200625,candle=GREEN
# date=20200626,candle=RED
# date=20200629,candle=RED
# date=20200630,candle=GREEN
# date=20200701,candle=GREEN
# date=20200702,candle=GREEN
# date=20200706,candle=GREEN
# date=20200707,candle=GREEN
# date=20200708,candle=GREEN
# date=20200709,candle=RED
# date=20200710,candle=RED
# date=20200713,candle=GREEN
# date=20200714,candle=GREEN
# date=20200715,candle=RED
# date=20200716,candle=RED
# date=20200717,candle=RED
# date=20200720,candle=GREEN
# date=20200721,candle=RED
# date=20200722,candle=GREEN
# date=20200723,candle=RED
# date=20200724,candle=RED
# date=20200727,candle=RED
# date=20200728,candle=GREEN
# date=20200729,candle=GREEN
# date=20200730,candle=GREEN
# date=20200731,candle=RED
# date=20200803,candle=RED
# date=20200804,candle=GREEN
# date=20200805,candle=RED
# date=20200806,candle=GREEN
# date=20200807,candle=GREEN
# date=20200810,candle=GREEN
# date=20200811,candle=RED
# date=20200812,candle=GREEN
# date=20200813,candle=GREEN
# date=20200814,candle=RED
# date=20200817,candle=GREEN
# date=20200818,candle=GREEN
# date=20200819,candle=RED
# date=20200820,candle=GREEN
# date=20200821,candle=GREEN
# date=20200824,candle=RED
# date=20200825,candle=RED
# date=20200826,candle=RED
# date=20200827,candle=RED
# date=20200828,candle=RED
# date=20200831,candle=RED
# date=20200901,candle=RED
# date=20200902,candle=RED
# date=20200903,candle=RED
# date=20200904,candle=GREEN
# date=20200908,candle=RED
# date=20200909,candle=RED
# date=20200910,candle=GREEN
# date=20200911,candle=RED
# date=20200914,candle=RED
# date=20200915,candle=GREEN
# date=20200916,candle=RED
# date=20200917,candle=GREEN
# date=20200918,candle=RED
# date=20200921,candle=RED
# date=20200922,candle=RED
# date=20200923,candle=RED
# date=20200924,candle=RED
# date=20200925,candle=GREEN
# date=20200928,candle=GREEN
# date=20200929,candle=RED
# date=20200930,candle=GREEN
# date=20201001,candle=GREEN
# date=20201002,candle=GREEN
# date=20201005,candle=GREEN
# date=20201006,candle=RED
# date=20201007,candle=GREEN
# date=20201008,candle=RED
# date=20201009,candle=GREEN
# date=20201012,candle=RED
# date=20201013,candle=RED
# date=20201014,candle=RED
# date=20201015,candle=GREEN
# date=20201016,candle=GREEN
# date=20201019,candle=GREEN
# date=20201020,candle=GREEN
# date=20201021,candle=GREEN
# date=20201022,candle=GREEN
# date=20201023,candle=RED
# date=20201026,candle=GREEN
# date=20201027,candle=RED
# date=20201028,candle=RED
# date=20201029,candle=GREEN
# date=20201030,candle=GREEN
# date=20201102,candle=RED
# date=20201103,candle=RED
# date=20201104,candle=GREEN
# date=20201105,candle=GREEN
# date=20201106,candle=RED
# date=20201109,candle=RED
# date=20201110,candle=GREEN
# date=20201111,candle=RED
# date=20201112,candle=RED
# date=20201113,candle=GREEN
# date=20201116,candle=RED
# date=20201117,candle=RED
# date=20201118,candle=RED
# date=20201119,candle=RED
# date=20201120,candle=RED
# date=20201123,candle=GREEN
# date=20201124,candle=RED
# date=20201125,candle=RED
# date=20201127,candle=RED
# date=20201130,candle=RED
# date=20201201,candle=RED
# date=20201202,candle=RED
# date=20201203,candle=GREEN
# date=20201204,candle=GREEN
# date=20201207,candle=GREEN
# date=20201208,candle=GREEN
# date=20201209,candle=RED
# date=20201210,candle=RED
# date=20201211,candle=GREEN
# date=20201214,candle=GREEN
# date=20201215,candle=GREEN
# date=20201216,candle=RED
# date=20201217,candle=GREEN
# date=20201218,candle=RED
# date=20201221,candle=GREEN
# date=20201222,candle=RED
# date=20201223,candle=GREEN
# date=20201224,candle=GREEN
# date=20201228,candle=RED
# date=20201229,candle=GREEN
# date=20201230,candle=GREEN
# date=20201231,candle=RED

# %% [markdown]
# ### Starting price difference - green (increase) and red (decrease) indicators for the first 5 mins of each date

# %%
dateTimeCandleSP = [] #(date,time,color,StrikePrice,StockPrice)
date = trainingSet[0][0]
openPrice = trainingSet[0][11]
skipDate = False
#indices: 0=Date, 1=TimeBarStart, 13= UnderCloseAskPrice, 11=UnderOpenAskPrice
for index,row in enumerate(trainingSet):
    #we are looking for the UnderOpenAskPrice(UOAP) at 9:30:00 AM (the first time it occurs) 
    #we are looking for the UnderOpenAskPrice (UOAP) at 9:36:00 AM (the last time it occurs)
    #then we subtract the 9:35:00 AM time by the 9:30:00 AM time
    
    if date == row[0]:
        if skipDate:
            continue
        #lastPrice = row["UnderCloseAskPrice"]
        prevRow = row
        #if time is past 9:35AM, then use the latest 9:35AM (if it doesn't exist, then use the current row's time)
        time = row[1]
        if not beforeTime(time,"9:36:00 AM"):
            #calculate starting price difference
            
            #if 9:35 exists
            if prevRow[1] == "9:35:00 AM":
                #we take the UnderCloseAskPrice
                lastPrice = prevRow[13]
            else:
                #if 9:35 doesn't exist
                #if 9:36 exists, then take the open price, otherwise skip this date
                if time == "9:36:00 AM":
                    lastPrice = row[11]
                else:
                    skipDate = True
                    continue
            
            """
            diff = lastPrice - openPrice
            if math.isnan(diff):
                #either openPrice or lastPrice doesn't exist
                skipDate = True
                continue
            #print("date={},lastPrice={}".format(date,lastPrice))
            if diff >= 0:
                #green start
                dateTimeCandleSP.append((date,time,"GREEN",math.ceil(lastPrice),lastPrice))
            else:
                dateTimeCandleSP.append((date,time,"RED",math.floor(lastPrice),lastPrice))
            """
            candleType = dateToCandle[date]
            dateTimeCandleSP.append((date,time,candleType,math.ceil(lastPrice),lastPrice))
            skipDate = True
    else:
        #we found new date, get the green/red bar for the previous date, reinitialize some variables
        date = row[0]
        openPrice = row[11]
        skipDate = False

# %%
#(date,time,color,StrikePrice,StockPrice)
dateTimeCandleSP
# Out:
# [(20200103, '9:36:00 AM', 'GREEN', 323, 322.41),
#  (20200106, '9:36:00 AM', 'GREEN', 322, 321.24),
#  (20200108, '9:36:00 AM', 'GREEN', 324, 323.4),
#  (20200110, '9:36:00 AM', 'RED', 327, 326.84),
#  (20200113, '9:36:00 AM', 'RED', 327, 326.18),
#  (20200115, '9:36:00 AM', 'GREEN', 329, 328.08),
#  (20200117, '9:36:00 AM', 'RED', 332, 331.45),
#  (20200121, '9:36:00 AM', 'GREEN', 332, 331.4),
#  (20200122, '9:36:00 AM', 'GREEN', 333, 332.44),
#  (20200124, '9:36:00 AM', 'RED', 333, 332.17),
#  (20200127, '9:36:00 AM', 'GREEN', 324, 323.77),
#  (20200129, '9:36:00 AM', 'RED', 329, 328.41),
#  (20200131, '9:36:00 AM', 'RED', 327, 326.16),
#  (20200203, '9:36:00 AM', 'GREEN', 325, 324.16),
#  (20200205, '9:36:00 AM', 'RED', 332, 331.93),
#  (20200207, '9:36:00 AM', 'RED', 333, 332.26),
#  (20200210, '9:36:00 AM', 'GREEN', 333, 332.14),
#  (20200212, '9:36:00 AM', 'GREEN', 338, 337.03),
#  (20200214, '9:36:00 AM', 'GREEN', 338, 337.51),
#  (20200218, '9:36:00 AM', 'GREEN', 337, 337.0),
#  (20200219, '9:36:00 AM', 'GREEN', 338, 337.9),
#  (20200221, '9:36:00 AM', 'RED', 336, 335.27),
#  (20200224, '9:36:00 AM', 'GREEN', 325, 324.4),
#  (20200226, '9:36:00 AM', 'GREEN', 315, 314.99)]

# %%
#---------------comeback1
#Make the df smaller (i.e. for each date, delete rows that aren't the same CallPut and StrikePrice)
#Also delete the times that are >= 4:00:00 PM

# %%
#if the candle is green then we want to buy a call
#if call then you look for the UnderOpenAskPrice at 9:36:00 AM and round that up to next whole number, this gets the Call_SP
#then we look for the Call_SP and see what the OpenTradePrice is at 9:36:00 AM

#if the candle is red then we want to buy a put
#if put then you look for the UnderOpenAskPrice at 9:36:00 AM and round that down to next whole number, this gets the Put_SP
#then we look for the Put_SP and see what the OpenTradePrice is at 9:36:00 AM

dtcspIdx = 0
dfStartIdx = 0
dateWithOTP = [] #(date, time, CallPut, SP, OTP)
for dtcsp in dateTimeCandleSP:
    #print("dateWithOTP: {}".format(dateWithOTP))
    date, time, color, strikeP = dtcsp[0],dtcsp[1],dtcsp[2], dtcsp[3]
    for index,row in enumerate(trainingSet[dfStartIdx:],dfStartIdx):
        if color == "GREEN":
            #This is call, get OpenTradePrice(OTP) at 9:36AM
            #Match Date, Time, Call=C, StrikePrice
            if row[0] == date and row[1] == time and row[3] == "C" and row[4] == strikeP:
                dateWithOTP.append((date,time,"C",strikeP,row[6]))
                #update for next iteration of dtcsp
                dfStartIdx = index + 1
                break
        else:
            #This is put, get OpenTradePrice(OTP) at 9:36AM
            #Match Date, Time, Call=P, StrikePrice
            if row[0] == date and row[1] == time and row[3] == "P" and row[4] == strikeP:
                dateWithOTP.append((date,time,"P",strikeP,row[6]))
                #update for next iteration of dtcsp
                dfStartIdx = index + 1
                break

# %%
#(date, time, CallPut, SP, OTP)
print("(date, time,CallPut, SP, OTP)")
dateWithOTP
# Out:
# (date, time,CallPut, SP, OTP)
# [(20200103, '9:36:00 AM', 'C', 323, 0.43),
#  (20200106, '9:36:00 AM', 'C', 322, 0.31),
#  (20200108, '9:36:00 AM', 'C', 324, 0.39),
#  (20200110, '9:36:00 AM', 'P', 327, 0.55),
#  (20200113, '9:36:00 AM', 'P', 327, 1.0),
#  (20200115, '9:36:00 AM', 'C', 329, 0.19),
#  (20200117, '9:36:00 AM', 'P', 332, 0.8),
#  (20200121, '9:36:00 AM', 'C', 332, 0.23),
#  (20200122, '9:36:00 AM', 'C', 333, 0.23),
#  (20200124, '9:36:00 AM', 'P', 333, 1.01),
#  (20200127, '9:36:00 AM', 'C', 324, 1.06),
#  (20200129, '9:36:00 AM', 'P', 329, 1.18),
#  (20200131, '9:36:00 AM', 'P', 327, 1.33),
#  (20200203, '9:36:00 AM', 'C', 325, 0.5),
#  (20200205, '9:36:00 AM', 'P', 332, 0.79),
#  (20200207, '9:36:00 AM', 'P', 333, 1.22),
#  (20200210, '9:36:00 AM', 'C', 333, 0.31),
#  (20200212, '9:36:00 AM', 'C', 338, 0.14),
#  (20200214, '9:36:00 AM', 'C', 338, 0.37),
#  (20200218, '9:36:00 AM', 'C', 337, 0.65),
#  (20200219, '9:36:00 AM', 'C', 338, 0.45),
#  (20200221, '9:36:00 AM', 'P', 336, 1.52),
#  (20200224, '9:36:00 AM', 'C', 325, 1.28),
#  (20200226, '9:36:00 AM', 'C', 315, 1.73)]

# %% [markdown]
# #### For each date,SP,CallPut in dateWithOTP, find the maximum of the hightradeprice and time (b/w 9:37:00 AM to 3:59:00 PM

# %%
dfStartIdx = 0
#Date	TimeBarStart	Ticker	CallPut	Strike	ExpirationDate	OpenTradePrice	HighTradePrice	LowTradePrice	CloseTradePrice	
dateTimeMaxHTP = [(0,0,0,0,0) for _ in range(len(dateWithOTP))] #[date,time,CallPut,SP,maxHTP]
prevDate = dateWithOTP[0][0]
N = len(trainingSet)
curDfLen = N
for dOTPidx, (date,_,CallPut,sp,_) in enumerate(dateWithOTP):
    #print("Checking for date={},CallPut={},sp={}".format(date,CallPut,sp))
    maxHTP = -1
    doSameDate = False
    for index,row in enumerate(trainingSet[dfStartIdx:],dfStartIdx):
        #print("date={}: index,dfStartIdx,N-dfStartIdx-1: {},{},{}".format(date,index,dfStartIdx,N-dfStartIdx-1))
        #print("htp={},maxHTP={},time={}".format(row[7],maxHTP,row[1]))
        if index == N-1: #index == N - dfStartIdx - 2:
            #needed this one here to check for end index, which can contain time inside the timeframe we want
            #print("if4.1-----------------------------------------")
            #case 1 - we're done with prev date
            dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)

            #initialize variables for next iteration of dateWithOTP
            dfStartIdx = index + 1
            prevDate = row[0]
            maxHTP = -1
            break
            
        if beforeTime(row[1],"9:37:00 AM") or afterTime(row[1],"3:59:00 PM"): 
            if index == N-1: #index == N - dfStartIdx - 2:
                #need this one here again because the last index may have time that is outside of timeframe
                #print("if4.1-----------------------------------------")
                #case 1 - we're done with prev date
                dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)
            
                #initialize variables for next iteration of dateWithOTP
                dfStartIdx = index + 1
                prevDate = row[0]
                maxHTP = -1
                break
            continue
        elif date == row[0] and CallPut == row[3] and sp == row[4]:
            #print("if1")
            #print("row: {}".format(list(row)))
            #Check if there's a new max HTP
            #print("htp={},maxHTP={},time={}".format(row[7],maxHTP,row[1]))
            if row[7] > maxHTP:
                #print("if2")
                #print("update for maxHTP: {}".format(row[7]))
                maxHTP = row[7]
                maxHTPTime = row[1]
        elif date != row[0]:
            #print("if3")
            #date doesn't match, so we're done searching for previous date OR this date has no value in df
            if maxHTP != -1: #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMaxHTP  
                #print("if4")
                #case 1 - we're done with prev date
                dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)
            
                #initialize variables for next iteration of dateWithOTP
                dfStartIdx = index + 1
                prevDate = row[0]
                maxHTP = -1
                break
            elif index == N-1: #index == N - dfStartIdx - 2:
                #print("if4.1-----------------------------------------")
                #case 1 - we're done with prev date
                dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)
            
                #initialize variables for next iteration of dateWithOTP
                dfStartIdx = index + 1
                prevDate = row[0]
                maxHTP = -1
                break
            else:
                #print('if5')
                #Case 2 - date has no value in df, so doesn't exist in dateWithOTP
                #keep iterating until we past this date and until we found the date that matches dateWithOTP
                dfStartIdx = index + 1
                #print("dfStartIdx: {}".format(dfStartIdx))
                for indexb,rowb in enumerate(trainingSet[dfStartIdx:],dfStartIdx):
                    if rowb[0] == date:
                        #print("if6")
                        prevDate = rowb[0]
                        dfStartIdx = indexb
                        doSameDate = True #found matching date so now iterate from that as startIdx to cover it instead of using current for loop
                        break
                if doSameDate:
                    #print("if7")
                    break
            

    if doSameDate:
        #print("if7.2")
        for index,row in enumerate(trainingSet[dfStartIdx:],dfStartIdx):
            #print("index,dfStartIdx,N-dfStartIdx-1: {},{},{}".format(index,dfStartIdx,N-dfStartIdx-1))
            if index == N-1: #N - dfStartIdx - 2: # 80352 - 41175 # - 1
                    #print("if11")
                    #reached the last index in df, so update for maxHTP
                    #case 1 - we're done with prev date
                    dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)

                    #initialize variables for next iteration of dateWithOTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    maxHTP = -1
                    break
                    
            if beforeTime(row[1],"9:37:00 AM") or afterTime(row[1],"3:59:00 PM"):
                if index == N-1: #N - dfStartIdx - 2: # 80352 - 41175 # - 1
                    #print("if11")
                    #reached the last index in df, so update for maxHTP
                    #case 1 - we're done with prev date
                    dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)

                    #initialize variables for next iteration of dateWithOTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    maxHTP = -1
                    break
                continue
            elif date == row[0] and CallPut == row[3] and sp == row[4]:
                #print("if8")
                #print("row: {}".format(list(row)))
                #Check if there's a new max HTP
                #print("htp={},maxHTP={},time={}".format(row[7],maxHTP,row[1]))
                if row[7] > maxHTP:
                    #print("if9")
                    #print("update for maxHTP: {}".format(row[7]))
                    maxHTP = row[7]
                    maxHTPTime = row[1]
            elif date != row[0]:
                #date doesn't match, so we're done searching for previous date OR this date has no value in df
                #print("if10")
                if maxHTP != -1: #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMaxHTP 
                    #case 1 - we're done with prev date
                    dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)

                    #initialize variables for next iteration of dateWithOTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    maxHTP = -1
                    break

# %%
dateTimeMaxHTP
# Out:
# [(20200103, '1:03:00 PM', 'C', 323, 0.7),
#  (20200106, '3:59:00 PM', 'C', 322, 1.65),
#  (20200108, '3:29:00 PM', 'C', 324, 1.78),
#  (20200110, '3:43:00 PM', 'P', 327, 1.78),
#  (20200113, '9:42:00 AM', 'P', 327, 1.2),
#  (20200115, '11:04:00 AM', 'C', 329, 0.44),
#  (20200117, '11:23:00 AM', 'P', 332, 1.03),
#  (20200121, '11:57:00 AM', 'C', 332, 0.36),
#  (20200122, '9:48:00 AM', 'C', 333, 0.32),
#  (20200124, '2:24:00 PM', 'P', 333, 5.49),
#  (20200127, '9:52:00 AM', 'C', 324, 1.49),
#  (20200129, '10:12:00 AM', 'P', 329, 2.69),
#  (20200131, '3:42:00 PM', 'P', 327, 6.16),
#  (20200203, '10:30:00 AM', 'C', 325, 1.5),
#  (20200205, '10:41:00 AM', 'P', 332, 1.48),
#  (20200207, '2:13:00 PM', 'P', 333, 1.45),
#  (20200210, '3:59:00 PM', 'C', 333, 1.64),
#  (20200212, '9:40:00 AM', 'C', 338, 0.2),
#  (20200214, '9:40:00 AM', 'C', 338, 0.32),
#  (20200218, '9:42:00 AM', 'C', 337, 0.65),
#  (20200219, '2:45:00 PM', 'C', 338, 1.1),
#  (20200221, '1:54:00 PM', 'P', 336, 3.38),
#  (20200224, '10:01:00 AM', 'C', 325, 1.79),
#  (20200226, '10:52:00 AM', 'C', 315, 3.53)]

# %% [markdown]
# #### Find the minimum of the option (LowTradePrice) from 9:37:00 AM to the maxHTP time
# #### If the max time occurs at 9:37:00 AM then find the minimum LowTradePrice of the option from 9:37:00 AM to the end of the day

# %%
dfStartIdx = 0
#Date	TimeBarStart	Ticker	CallPut	Strike	ExpirationDate	OpenTradePrice	HighTradePrice	LowTradePrice	CloseTradePrice	
dateTimeMinLTP = [(0,0,0,0,0) for _ in range(len(dateTimeMaxHTP))] #[date,time,CallPut,SP,minLTP]
prevDate = dateTimeMaxHTP[0][0]
N = len(trainingSet)
curDfLen = N
for dTMidx, (date,maxHTPTime,CallPut,sp,_) in enumerate(dateTimeMaxHTP):
    
    while int(prevDate) < date:
        #if the row's date is not part of our dateTimeMaxHTP, then we keep moving to next row
        dfStartIdx += 1
        if dfStartIdx >= N - 1:
            break
        #print("dfStartIdx={}".format(dfStartIdx))
        #print("N = {}".format(N))
        #print("dfStartIdx={},trainingSet[dfStartIdx]={}".format(dfStartIdx,trainingSet[dfStartIdx]))
        prevDate = trainingSet[dfStartIdx][0]


    #print("Checking for date={},maxHTPTime={},CallPut={},sp={}".format(date,maxHTPTime,CallPut,sp))
    minLTP = float("inf")
    doSameDate = False
    
    if maxHTPTime == "9:37:00 AM":
        #print("inside maxHTPTime == 9:37:00 AM")
        #if the max time occurs at 9:37:00 AM then find the minimum LowTradePrice of the option from 9:37:00 AM to the end of the day
        for index,row in enumerate(trainingSet[dfStartIdx:],dfStartIdx):
            #print("index,dfStartIdx,N-dfStartIdx-1,time: {},{},{},{}".format(index,dfStartIdx,N-dfStartIdx-1,row[1]))
            #print("htp={},minLTP={},time={}".format(row[8],minLTP,row[1]))
            if index == N-1: #index == N - dfStartIdx - 2:
                #case 1 - we're done with prev date
                #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                #initialize variables for next iteration of dateTimeMaxHTP
                dfStartIdx = index + 1
                prevDate = row[0]
                minLTP = float("inf")
                break

            #want 9:37AM to end of day
            #otherwise toss out this row
            if beforeTime(row[1],"9:37:00 AM") or afterTime(row[1],"3:59:00 PM"):
                if index == N-1: #index == N - dfStartIdx - 2:
                    #case 1 - we're done with prev date
                    #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                    dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                    #initialize variables for next iteration of dateTimeMaxHTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    minLTP = float("inf")
                    break
                continue
            elif date == row[0] and CallPut == row[3] and sp == row[4]:
                #print("row: {}".format(list(row)))
                #Check if there's a new max HTP
                #print("htp={},minLTP={},time={}".format(row[8],minLTP,row[1]))
                if row[8] < minLTP:
                    #print("update for minLTP: {}".format(row[8]))
                    minLTP = row[8]
                    minLTPTime = row[1]
            elif date != row[0]:
                #date doesn't match, so we're done searching for previous date OR this date has no value in df
                if minLTP != float("inf"): #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMinLTP  
                    #case 1 - we're done with prev date
                    #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                    dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                    #initialize variables for next iteration of dateTimeMaxHTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    minLTP = float("inf")
                    break
                elif index == N-1: #index == N - dfStartIdx - 2:
                    #case 1 - we're done with prev date
                    #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                    dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                    #initialize variables for next iteration of dateTimeMaxHTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    minLTP = float("inf")
                    break
                else:
                    #print('if5 - date has no value in df')
                    #Case 2 - date has no value in df, so doesn't exist in dateTimeMaxHTP
                    #keep iterating until we past this date and until we found the date that matches dateTimeMaxHTP
                    dfStartIdx = index + 1
                    #print("dfStartIdx: {}".format(dfStartIdx))
                    for indexb,rowb in enumerate(trainingSet[dfStartIdx:],dfStartIdx):
                        if rowb[0] == date:
                            prevDate = rowb[0]
                            dfStartIdx = indexb
                            doSameDate = True #found matching date so now iterate from that as startIdx to cover it instead of using current for loop
                            break
                    if doSameDate:
                        break
            

            if doSameDate:
                for index,row in enumerate(trainingSet[dfStartIdx:],dfStartIdx):
                    #print("index,dfStartIdx,N-dfStartIdx-1: {},{},{}".format(index,dfStartIdx,N-dfStartIdx-1))
                    if minLTP != float("inf"): #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMinLTP  
                        #case 1 - we're done with prev date
                        #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                        dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                        #initialize variables for next iteration of dateTimeMaxHTP
                        dfStartIdx = index + 1
                        prevDate = row[0]
                        minLTP = float("inf")
                        break

                    #want 9:37AM to end of day
                    #otherwise toss out this row
                    if beforeTime(row[1],"9:37:00 AM") or afterTime(row[1],"3:59:00 PM"):
                        if index == N-1: #N - dfStartIdx - 2: # 80352 - 41175 # - 1
                            #reached the last index in df, so update for minLTP
                            #case 1 - we're done with prev date
                            #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                            dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                            #initialize variables for next iteration of dateTimeMaxHTP
                            dfStartIdx = index + 1
                            prevDate = row[0]
                            minLTP = float("inf")
                            break
                        continue
                    elif date == row[0] and CallPut == row[3] and sp == row[4]:
                        #print("row: {}".format(list(row)))
                        #Check if there's a new max HTP
                        #print("htp={},minLTP={},time={}".format(row[8],minLTP,row[1]))
                        if row[8] < minLTP:
                            #print("update for minLTP: {}".format(row[8]))
                            minLTP = row[8]
                            minLTPTime = row[1]
                    elif date != row[0]:
                        #date doesn't match, so we're done searching for previous date OR this date has no value in df
                        if minLTP != float("inf"): #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMinLTP 
                            #case 1 - we're done with prev date
                            #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                            dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                            #initialize variables for next iteration of dateTimeMaxHTP
                            dfStartIdx = index + 1
                            prevDate = row[0]
                            minLTP = float("inf")
                            break
    else:
        #print("NOT inside maxHTPTime == 9:37:00 AM")
        #max occurs after 9:37AM - find the minimum of the option (LowTradePrice) from 9:37:00 AM to the max HTP time
        for index,row in df.iloc[dfStartIdx:].iterrows():
            #print("index,dfStartIdx,N-dfStartIdx-1: {},{},{}".format(index,dfStartIdx,N-dfStartIdx-1))
            #print("htp={},minLTP={},time={}".format(row[8],minLTP,row[1]))
            if index == N-1: #index == N - dfStartIdx - 2:
                #case 1 - we're done with prev date
                #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                #initialize variables for next iteration of dateTimeMaxHTP
                dfStartIdx = index + 1
                prevDate = row[0]
                minLTP = float("inf")
                break

            #want 9:37AM to maxHTP time
            #toss out others
            if beforeTime(row[1],"9:37:00 AM") or afterTime(row[1],maxHTPTime):
                if index == N-1: #index == N - dfStartIdx - 2:
                    #case 1 - we're done with prev date
                    #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                    dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                    #initialize variables for next iteration of dateTimeMaxHTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    minLTP = float("inf")
                    break
                continue
            elif date == row[0] and CallPut == row[3] and sp == row[4]:
                #print("row: {}".format(list(row)))
                #Check if there's a new max HTP
                #print("htp={},minLTP={},time={}".format(row[8],minLTP,row[1]))
                if row[8] < minLTP:
                    #print("update for minLTP: {}".format(row[8]))
                    minLTP = row[8]
                    minLTPTime = row[1]
            elif date != row[0]:
                #date doesn't match, so we're done searching for previous date OR this date has no value in df
                if minLTP != float("inf"): #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMinLTP  
                    #case 1 - we're done with prev date
                    #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                    dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                    #initialize variables for next iteration of dateTimeMaxHTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    minLTP = float("inf")
                    break
                elif index == N-1: #index == N - dfStartIdx - 2:
                    #case 1 - we're done with prev date
                    #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                    dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                    #initialize variables for next iteration of dateTimeMaxHTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    minLTP = float("inf")
                    break
                else:
                    #print('if5')
                    #Case 2 - date has no value in df, so doesn't exist in dateTimeMaxHTP
                    #keep iterating until we past this date and until we found the date that matches dateTimeMaxHTP
                    dfStartIdx = index + 1
                    #print("dfStartIdx: {}".format(dfStartIdx))
                    for indexb,rowb in df.iloc[dfStartIdx:].iterrows():
                        if rowb[0] == date:
                            prevDate = rowb[0]
                            dfStartIdx = indexb
                            doSameDate = True #found matching date so now iterate from that as startIdx to cover it instead of using current for loop
                            break
                    if doSameDate:
                        break
            

            if doSameDate:
                for index,row in df.iloc[dfStartIdx:].iterrows():
                    #print("index,dfStartIdx,N-dfStartIdx-1: {},{},{}".format(index,dfStartIdx,N-dfStartIdx-1))
                    if minLTP != float("inf"): #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMinLTP  
                        #case 1 - we're done with prev date
                        #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                        #print("prevDate={},minLTPTime={},CallPut={},sp={},minLTP={}".format(prevDate,minLTPTime,CallPut,sp,minLTP))
                        dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                        #initialize variables for next iteration of dateTimeMaxHTP
                        dfStartIdx = index + 1
                        prevDate = row[0]
                        minLTP = float("inf")
                        break

                    if beforeTime(row[1],"9:37:00 AM") or afterTime(row[1],maxHTPTime):
                        if index == N-1: #N - dfStartIdx - 2: # 80352 - 41175 # - 1
                            #reached the last index in df, so update for minLTP
                            #case 1 - we're done with prev date
                            dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                            #initialize variables for next iteration of dateTimeMaxHTP
                            dfStartIdx = index + 1
                            prevDate = row[0]
                            minLTP = float("inf")
                            break
                        continue
                    elif date == row[0] and CallPut == row[3] and sp == row[4]:
                        #print("row: {}".format(list(row)))
                        #Check if there's a new max HTP
                        #print("htp={},minLTP={},time={}".format(row[8],minLTP,row[1]))
                        if row[8] < minLTP:
                            #print("update for minLTP: {}".format(row[8]))
                            minLTP = row[8]
                            minLTPTime = row[1]
                    elif date != row[0]:
                        #date doesn't match, so we're done searching for previous date OR this date has no value in df
                        if minLTP != float("inf"): #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMinLTP 
                            #case 1 - we're done with prev date
                            dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                            #initialize variables for next iteration of dateTimeMaxHTP
                            dfStartIdx = index + 1
                            prevDate = row[0]
                            minLTP = float("inf")
                            break

# %%
dateWithOTP
# Out:
# [(20200103, '9:36:00 AM', 'C', 323, 0.43),
#  (20200106, '9:36:00 AM', 'C', 322, 0.31),
#  (20200108, '9:36:00 AM', 'C', 324, 0.39),
#  (20200110, '9:36:00 AM', 'P', 327, 0.55),
#  (20200113, '9:36:00 AM', 'P', 327, 1.0),
#  (20200115, '9:36:00 AM', 'C', 329, 0.19),
#  (20200117, '9:36:00 AM', 'P', 332, 0.8),
#  (20200121, '9:36:00 AM', 'C', 332, 0.23),
#  (20200122, '9:36:00 AM', 'C', 333, 0.23),
#  (20200124, '9:36:00 AM', 'P', 333, 1.01),
#  (20200127, '9:36:00 AM', 'C', 324, 1.06),
#  (20200129, '9:36:00 AM', 'P', 329, 1.18),
#  (20200131, '9:36:00 AM', 'P', 327, 1.33),
#  (20200203, '9:36:00 AM', 'C', 325, 0.5),
#  (20200205, '9:36:00 AM', 'P', 332, 0.79),
#  (20200207, '9:36:00 AM', 'P', 333, 1.22),
#  (20200210, '9:36:00 AM', 'C', 333, 0.31),
#  (20200212, '9:36:00 AM', 'C', 338, 0.14),
#  (20200214, '9:36:00 AM', 'C', 338, 0.37),
#  (20200218, '9:36:00 AM', 'C', 337, 0.65),
#  (20200219, '9:36:00 AM', 'C', 338, 0.45),
#  (20200221, '9:36:00 AM', 'P', 336, 1.52),
#  (20200224, '9:36:00 AM', 'C', 325, 1.28),
#  (20200226, '9:36:00 AM', 'C', 315, 1.73)]

# %%
#[date,time,CallPut,sp,minLTP]
dateTimeMinLTP
# Out:
# [(20200103, '11:10:00 AM', 'C', 323, 0.2),
#  (20200106, '9:38:00 AM', 'C', 322, 0.24),
#  (20200108, '10:49:00 AM', 'C', 324, 0.21),
#  (20200110, '10:05:00 AM', 'P', 327, 0.25),
#  (20200113, '9:38:00 AM', 'P', 327, 0.88),
#  (20200115, '9:45:00 AM', 'C', 329, 0.16),
#  (20200117, '10:29:00 AM', 'P', 332, 0.5),
#  (20200121, '11:00:00 AM', 'C', 332, 0.07),
#  (20200122, '9:37:00 AM', 'C', 333, 0.22),
#  (20200124, '9:38:00 AM', 'P', 333, 0.89),
#  (20200127, '9:37:00 AM', 'C', 324, 1.0),
#  (20200129, '9:37:00 AM', 'P', 329, 1.15),
#  (20200131, '9:39:00 AM', 'P', 327, 0.99),
#  (20200203, '9:41:00 AM', 'C', 325, 0.51),
#  (20200205, '10:05:00 AM', 'P', 332, 0.51),
#  (20200207, '11:31:00 AM', 'P', 333, 0.28),
#  (20200210, '9:50:00 AM', 'C', 333, 0.26),
#  (20200212, '9:37:00 AM', 'C', 338, 0.14),
#  (20200214, '9:37:00 AM', 'C', 338, 0.25),
#  (20200218, '9:37:00 AM', 'C', 337, 0.43),
#  (20200219, '10:13:00 AM', 'C', 338, 0.42),
#  (20200221, '9:37:00 AM', 'P', 336, 1.27),
#  (20200221, '9:42:00 AM', 'C', 325, 1.32),
#  (20200226, '10:06:00 AM', 'C', 315, 1.63)]

# %%
dateTimeMaxHTP
# Out:
# [(20200103, '1:03:00 PM', 'C', 323, 0.7),
#  (20200106, '3:59:00 PM', 'C', 322, 1.65),
#  (20200108, '3:29:00 PM', 'C', 324, 1.78),
#  (20200110, '3:43:00 PM', 'P', 327, 1.78),
#  (20200113, '9:42:00 AM', 'P', 327, 1.2),
#  (20200115, '11:04:00 AM', 'C', 329, 0.44),
#  (20200117, '11:23:00 AM', 'P', 332, 1.03),
#  (20200121, '11:57:00 AM', 'C', 332, 0.36),
#  (20200122, '9:48:00 AM', 'C', 333, 0.32),
#  (20200124, '2:24:00 PM', 'P', 333, 5.49),
#  (20200127, '9:52:00 AM', 'C', 324, 1.49),
#  (20200129, '10:12:00 AM', 'P', 329, 2.69),
#  (20200131, '3:42:00 PM', 'P', 327, 6.16),
#  (20200203, '10:30:00 AM', 'C', 325, 1.5),
#  (20200205, '10:41:00 AM', 'P', 332, 1.48),
#  (20200207, '2:13:00 PM', 'P', 333, 1.45),
#  (20200210, '3:59:00 PM', 'C', 333, 1.64),
#  (20200212, '9:40:00 AM', 'C', 338, 0.2),
#  (20200214, '9:40:00 AM', 'C', 338, 0.32),
#  (20200218, '9:42:00 AM', 'C', 337, 0.65),
#  (20200219, '2:45:00 PM', 'C', 338, 1.1),
#  (20200221, '1:54:00 PM', 'P', 336, 3.38),
#  (20200224, '10:01:00 AM', 'C', 325, 1.79),
#  (20200226, '10:52:00 AM', 'C', 315, 3.53)]

# %%
numValidDates = len(dateWithOTP)
mergedOtpLtpHtp = [(0,"Z",0,("Z",0),("Z",0),("Z",0))] * numValidDates #(date,CallPut,SP,(time1,OTP),(time2,minLTP),(time3,maxHTP))
for index in range(numValidDates):
    date = dateWithOTP[index][0]
    CallPut = dateWithOTP[index][2]
    SP = dateWithOTP[index][3]
    time1, OTP = dateWithOTP[index][1], dateWithOTP[index][4]
    time2, minLTP = dateTimeMinLTP[index][1], dateTimeMinLTP[index][4]
    time3, maxHTP = dateTimeMaxHTP[index][1], dateTimeMaxHTP[index][4]
    mergedOtpLtpHtp[index] = (date,CallPut,SP,(time1,OTP),(time2,minLTP),(time3,maxHTP))

# %%
mergedOtpLtpHtp
# Out:
# [(20200103,
#   'C',
#   323,
#   ('9:36:00 AM', 0.43),
#   ('11:10:00 AM', 0.2),
#   ('1:03:00 PM', 0.7)),
#  (20200106,
#   'C',
#   322,
#   ('9:36:00 AM', 0.31),
#   ('9:38:00 AM', 0.24),
#   ('3:59:00 PM', 1.65)),
#  (20200108,
#   'C',
#   324,
#   ('9:36:00 AM', 0.39),
#   ('10:49:00 AM', 0.21),
#   ('3:29:00 PM', 1.78)),
#  (20200110,
#   'P',
#   327,
#   ('9:36:00 AM', 0.55),
#   ('10:05:00 AM', 0.25),
#   ('3:43:00 PM', 1.78)),
#  (20200113,
#   'P',
#   327,
#   ('9:36:00 AM', 1.0),
#   ('9:38:00 AM', 0.88),
#   ('9:42:00 AM', 1.2)),
#  (20200115,
#   'C',
#   329,
#   ('9:36:00 AM', 0.19),
#   ('9:45:00 AM', 0.16),
#   ('11:04:00 AM', 0.44)),
#  (20200117,
#   'P',
#   332,
#   ('9:36:00 AM', 0.8),
#   ('10:29:00 AM', 0.5),
#   ('11:23:00 AM', 1.03)),
#  (20200121,
#   'C',
#   332,
#   ('9:36:00 AM', 0.23),
#   ('11:00:00 AM', 0.07),
#   ('11:57:00 AM', 0.36)),
#  (20200122,
#   'C',
#   333,
#   ('9:36:00 AM', 0.23),
#   ('9:37:00 AM', 0.22),
#   ('9:48:00 AM', 0.32)),
#  (20200124,
#   'P',
#   333,
#   ('9:36:00 AM', 1.01),
#   ('9:38:00 AM', 0.89),
#   ('2:24:00 PM', 5.49)),
#  (20200127,
#   'C',
#   324,
#   ('9:36:00 AM', 1.06),
#   ('9:37:00 AM', 1.0),
#   ('9:52:00 AM', 1.49)),
#  (20200129,
#   'P',
#   329,
#   ('9:36:00 AM', 1.18),
#   ('9:37:00 AM', 1.15),
#   ('10:12:00 AM', 2.69)),
#  (20200131,
#   'P',
#   327,
#   ('9:36:00 AM', 1.33),
#   ('9:39:00 AM', 0.99),
#   ('3:42:00 PM', 6.16)),
#  (20200203,
#   'C',
#   325,
#   ('9:36:00 AM', 0.5),
#   ('9:41:00 AM', 0.51),
#   ('10:30:00 AM', 1.5)),
#  (20200205,
#   'P',
#   332,
#   ('9:36:00 AM', 0.79),
#   ('10:05:00 AM', 0.51),
#   ('10:41:00 AM', 1.48)),
#  (20200207,
#   'P',
#   333,
#   ('9:36:00 AM', 1.22),
#   ('11:31:00 AM', 0.28),
#   ('2:13:00 PM', 1.45)),
#  (20200210,
#   'C',
#   333,
#   ('9:36:00 AM', 0.31),
#   ('9:50:00 AM', 0.26),
#   ('3:59:00 PM', 1.64)),
#  (20200212,
#   'C',
#   338,
#   ('9:36:00 AM', 0.14),
#   ('9:37:00 AM', 0.14),
#   ('9:40:00 AM', 0.2)),
#  (20200214,
#   'C',
#   338,
#   ('9:36:00 AM', 0.37),
#   ('9:37:00 AM', 0.25),
#   ('9:40:00 AM', 0.32)),
#  (20200218,
#   'C',
#   337,
#   ('9:36:00 AM', 0.65),
#   ('9:37:00 AM', 0.43),
#   ('9:42:00 AM', 0.65)),
#  (20200219,
#   'C',
#   338,
#   ('9:36:00 AM', 0.45),
#   ('10:13:00 AM', 0.42),
#   ('2:45:00 PM', 1.1)),
#  (20200221,
#   'P',
#   336,
#   ('9:36:00 AM', 1.52),
#   ('9:37:00 AM', 1.27),
#   ('1:54:00 PM', 3.38)),
#  (20200224,
#   'C',
#   325,
#   ('9:36:00 AM', 1.28),
#   ('9:42:00 AM', 1.32),
#   ('10:01:00 AM', 1.79)),
#  (20200226,
#   'C',
#   315,
#   ('9:36:00 AM', 1.73),
#   ('10:06:00 AM', 1.63),
#   ('10:52:00 AM', 3.53))]

# %%
value = 1 - ((2.26 - 2.22) / 2.26 * 100)
formatted_string = "{:.3f}".format(value)
print(formatted_string + "%")
# Out:
# -0.770%

# %% [raw]
# # Part 1
# ## For each date, find the percentage of change from OTP to minLTP
# ## Round the %change up to a whole number (e.g. 0%, 1%, 2%, ..., 99%, 100%)
# ## EDIT - WE WILL USE MARGINS OF 5% (e.g. 5%(0-5%],10%(5-10%],15%(10-15%],...,95%(90-95%],100%(95-100%])
#
# ## Create a mapping for %change to number of occurrence
# ## Select the %change with the highest occurrence, and then use that to make a limit buy for when the OTP drops by that percent
#
# # Part 2
# ## Check if the percent change of maxHTP and buyPrice to see the percent profit, then add that to profit dictionary (maps profit% to number of occurrence).
# ## Then that means we will always set up a limit sell for that percent profit

# %%
import collections
dropFromOTP = collections.defaultdict(int) #part 1
buyToMax = collections.defaultdict(int) #part 2
numValidDates = len(mergedOtpLtpHtp)
margin = 5 #this is our margin for our %
for index in range(numValidDates):
    time1, otp = mergedOtpLtpHtp[index][3][0], mergedOtpLtpHtp[index][3][1]
    time2, minLTP = mergedOtpLtpHtp[index][4][0], mergedOtpLtpHtp[index][4][1]
    time3, maxHTP = mergedOtpLtpHtp[index][5][0], mergedOtpLtpHtp[index][5][1]
    if afterTime(time2,time3):
        #failure date, we lose 50%
        dropPerc = -50
    else:
        #dropPerc = math.ceil((otp - minLTP) / otp * 100)
        dropPerc = (otp - minLTP) / otp * 100 # 93.222 --> 95
        dropPerc =  margin * math.ceil(dropPerc/margin)
    #print(otp,minLTP,dropPerc)
    dropFromOTP[dropPerc] += 1
    #print("otp={}, minLTP={}, dropPerc={}".format(otp,minLTP,dropPerc))
    
mostOccurredDropPerc = max(dropFromOTP, key=dropFromOTP.get)
print("mostOccurredDropPerc:{}".format(mostOccurredDropPerc))

for index in range(numValidDates):
    time1, otp = mergedOtpLtpHtp[index][3][0], mergedOtpLtpHtp[index][3][1]
    time2, minLTP = mergedOtpLtpHtp[index][4][0], mergedOtpLtpHtp[index][4][1]
    time3, maxHTP = mergedOtpLtpHtp[index][5][0], mergedOtpLtpHtp[index][5][1]
    #print("otp={}, minLTP={}, mostOccurredDropPerc={}, buyPriceGeneral={}".format(otp,minLTP,mostOccurredDropPerc,buyPriceGeneral))
    
    #percent profit from buyPriceGeneral --> maxHTP
    if afterTime(time2,time3):
        buyPriceGeneral = 0
        profitPerc = -50
    else:
        buyPriceGeneral = otp - mostOccurredDropPerc/100*otp
        profitPerc = math.floor((maxHTP - buyPriceGeneral) / maxHTP * 100)
    if buyPriceGeneral*0.5 >= minLTP:
        #if our minLTP can still drop very low (past 50% our buy) then we have a failure
        profitPerc = -50
    #print("otp={}, minLTP={}, mostOccurredDropPerc={}, buyPriceGeneral={}, profitPerc={}".format(otp,minLTP,mostOccurredDropPerc,buyPriceGeneral,profitPerc))
    buyToMax[profitPerc] += 1
temp = buyToMax[-50]
del buyToMax[-50]
mostOccuredBuyProfit = max(buyToMax, key=buyToMax.get) #excludes -50
print("mostOccuredBuyProfit:{}".format(mostOccuredBuyProfit))
buyToMax[-50] = temp
# Out:
# mostOccurredDropPerc:20
# mostOccuredBuyProfit:84

# %%
print("dropFromOTP: {}".format(dropFromOTP))
print("buyToMax: {}".format(buyToMax))
print("mostOccurredDropPerc: {}%".format(mostOccurredDropPerc))
print("mostOccuredBuyProfit: {}%".format(mostOccuredBuyProfit))
# Out:
# dropFromOTP: defaultdict(<class 'int'>, {55: 2, 25: 1, 50: 1, 15: 2, 20: 3, 40: 2, 70: 1, 5: 2, 10: 3, 30: 1, 0: 3, 80: 1, 35: 2})
# buyToMax: defaultdict(<class 'int'>, {50: 1, 84: 2, 82: 2, 75: 1, 33: 1, 65: 1, 37: 1, 42: 2, 85: 1, 43: 2, 64: 2, 73: 1, 57: 1, 7: 1, 20: 1, 67: 1, 60: 1, -50: 2})
# mostOccurredDropPerc: 20%
# mostOccuredBuyProfit: 84%

# %% [raw]
# #Reuse the code from above on the validation set so we can get the candle color, OTP, minLTP, and maxHTP for the new dataset

# %%
#takes in a dataset, and outputs date, color, SP, OTP, minLTP, and maxHTP
def datasetToMerged(validationSet):
    #PART 1 GETS Color and StrikePrice
    dateTimeCandleSP = [] #(date,time,color,StrikePrice,StockPrice)
    date = validationSet[0][0]
    openPrice = validationSet[0][11] #underopenaskprice
    skipDate = False
    #indices: 0=Date, 1=TimeBarStart, 13= UnderCloseAskPrice, 11=UnderOpenAskPrice
    for index,row in enumerate(validationSet):
        #we are looking for the UnderOpenAskPrice(UOAP) at 9:30:00 AM (the first time it occurs) 
        #we are looking for the UnderOpenAskPrice (UOAP) at 9:36:00 AM (the last time it occurs)
        #then we subtract the 9:35:00 AM time by the 9:30:00 AM time

        if date == row[0]:
            if skipDate:
                continue
            #lastPrice = row["UnderCloseAskPrice"]
            prevRow = row
            #if time is past 9:35AM, then use the latest 9:35AM (if it doesn't exist, then use the current row's time)
            time = row[1]
            if not beforeTime(time,"9:36:00 AM"):
                #calculate starting price difference

                #if 9:35 exists
                if prevRow[1] == "9:35:00 AM":
                    #we take the UnderCloseAskPrice
                    lastPrice = prevRow[13]
                else:
                    #if 9:35 doesn't exist
                    #if 9:36 exists, then take the open price, otherwise skip this date
                    if time == "9:36:00 AM":
                        lastPrice = row[11]
                    else:
                        skipDate = True
                        continue
                diff = lastPrice - openPrice
                if math.isnan(diff):
                    #either openPrice or lastPrice doesn't exist
                    skipDate = True
                    continue
                #print("date={},lastPrice={}".format(date,lastPrice))
                if diff >= 0:
                    #green start
                    dateTimeCandleSP.append((date,time,"GREEN",math.ceil(lastPrice),lastPrice))
                else:
                    dateTimeCandleSP.append((date,time,"RED",math.floor(lastPrice),lastPrice))
                skipDate = True
        else:
            #we found new date, get the green/red bar for the previous date, reinitialize some variables
            date = row[0]
            openPrice = row[11]
            skipDate = False

    #PART 2 GETS OTP
    dtcspIdx = 0
    dfStartIdx = 0
    dateWithOTP = [] #(date, time, CallPut, SP, OTP)
    for dtcsp in dateTimeCandleSP:
        #print("dateWithOTP: {}".format(dateWithOTP))
        date, time, color, strikeP = dtcsp[0],dtcsp[1],dtcsp[2], dtcsp[3]
        for index,row in enumerate(validationSet[dfStartIdx:],dfStartIdx):
            if color == "GREEN":
                #This is call, get OpenTradePrice(OTP) at 9:36AM
                #Match Date, Time, Call=C, StrikePrice
                if row[0] == date and row[1] == time and row[3] == "C" and row[4] == strikeP:
                    dateWithOTP.append((date,time,"C",strikeP,row[6]))
                    #update for next iteration of dtcsp
                    dfStartIdx = index + 1
                    break
            else:
                #This is put, get OpenTradePrice(OTP) at 9:36AM
                #Match Date, Time, Call=P, StrikePrice
                if row[0] == date and row[1] == time and row[3] == "P" and row[4] == strikeP:
                    dateWithOTP.append((date,time,"P",strikeP,row[6]))
                    #update for next iteration of dtcsp
                    dfStartIdx = index + 1
                    break
    #PART 4 GETS maxHTP
    dfStartIdx = 0
    #Date	TimeBarStart	Ticker	CallPut	Strike	ExpirationDate	OpenTradePrice	HighTradePrice	LowTradePrice	CloseTradePrice	
    dateTimeMaxHTP = [(0,0,0,0,0) for _ in range(len(dateWithOTP))] #[date,time,CallPut,SP,maxHTP]
    prevDate = dateWithOTP[0][0]
    N = len(validationSet)
    curDfLen = N
    for dOTPidx, (date,_,CallPut,sp,_) in enumerate(dateWithOTP):
        #print("Checking for date={},CallPut={},sp={}".format(date,CallPut,sp))
        maxHTP = -1
        doSameDate = False
        for index,row in enumerate(validationSet[dfStartIdx:],dfStartIdx):
            #print("index,dfStartIdx,N-dfStartIdx-1: {},{},{}".format(index,dfStartIdx,N-dfStartIdx-1))
            #print("htp={},maxHTP={},time={}".format(row[7],maxHTP,row[1]))
            if index == N-1: #index == N - dfStartIdx - 2:
                #needed this one here to check for end index, which can contain time inside the timeframe we want
                #print("if4.1-----------------------------------------")
                #case 1 - we're done with prev date
                dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)

                #initialize variables for next iteration of dateWithOTP
                dfStartIdx = index + 1
                prevDate = row[0]
                maxHTP = -1
                break

            if beforeTime(row[1],"9:37:00 AM") or afterTime(row[1],"3:59:00 PM"):
                if index == N-1: #index == N - dfStartIdx - 2:
                    #need this one here again because the last index may have time that is outside of timeframe
                    #print("if4.1-----------------------------------------")
                    #case 1 - we're done with prev date
                    dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)

                    #initialize variables for next iteration of dateWithOTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    maxHTP = -1
                    break
                continue
            elif date == row[0] and CallPut == row[3] and sp == row[4]:
                #print("if1")
                #print("row: {}".format(list(row)))
                #Check if there's a new max HTP
                #print("htp={},maxHTP={},time={}".format(row[7],maxHTP,row[1]))
                if row[7] > maxHTP:
                    #print("if2")
                    #print("update for maxHTP: {}".format(row[7]))
                    maxHTP = row[7]
                    maxHTPTime = row[1]
            elif date != row[0]:
                #print("if3")
                #date doesn't match, so we're done searching for previous date OR this date has no value in validationSet
                if maxHTP != -1: #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMaxHTP  
                    #print("if4")
                    #case 1 - we're done with prev date
                    dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)

                    #initialize variables for next iteration of dateWithOTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    maxHTP = -1
                    break
                elif index == N-1: #index == N - dfStartIdx - 2:
                    #print("if4.1-----------------------------------------")
                    #case 1 - we're done with prev date
                    dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)

                    #initialize variables for next iteration of dateWithOTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    maxHTP = -1
                    break
                else:
                    #print('if5')
                    #Case 2 - date has no value in validationSet, so doesn't exist in dateWithOTP
                    #keep iterating until we past this date and until we found the date that matches dateWithOTP
                    dfStartIdx = index + 1
                    #print("dfStartIdx: {}".format(dfStartIdx))
                    for indexb,rowb in enumerate(validationSet[dfStartIdx:],dfStartIdx):
                        if rowb[0] == date:
                            #print("if6")
                            prevDate = rowb[0]
                            dfStartIdx = indexb
                            doSameDate = True #found matching date so now iterate from that as startIdx to cover it instead of using current for loop
                            break
                    if doSameDate:
                        #print("if7")
                        break


        if doSameDate:
            #print("if7.2")
            for index,row in enumerate(validationSet[dfStartIdx:],dfStartIdx):
                #print("index,dfStartIdx,N-dfStartIdx-1: {},{},{}".format(index,dfStartIdx,N-dfStartIdx-1))
                if index == N-1: #N - dfStartIdx - 2: # 80352 - 41175 # - 1
                        #print("if11")
                        #reached the last index in validationSet, so update for maxHTP
                        #case 1 - we're done with prev date
                        dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)

                        #initialize variables for next iteration of dateWithOTP
                        dfStartIdx = index + 1
                        prevDate = row[0]
                        maxHTP = -1
                        break

                if beforeTime(row[1],"9:37:00 AM") or afterTime(row[1],"3:59:00 PM"):
                    if index == N-1: #N - dfStartIdx - 2: # 80352 - 41175 # - 1
                        #print("if11")
                        #reached the last index in validationSet, so update for maxHTP
                        #case 1 - we're done with prev date
                        dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)

                        #initialize variables for next iteration of dateWithOTP
                        dfStartIdx = index + 1
                        prevDate = row[0]
                        maxHTP = -1
                        break
                    continue
                elif date == row[0] and CallPut == row[3] and sp == row[4]:
                    #print("if8")
                    #print("row: {}".format(list(row)))
                    #Check if there's a new max HTP
                    #print("htp={},maxHTP={},time={}".format(row[7],maxHTP,row[1]))
                    if row[7] > maxHTP:
                        #print("if9")
                        #print("update for maxHTP: {}".format(row[7]))
                        maxHTP = row[7]
                        maxHTPTime = row[1]
                elif date != row[0]:
                    #date doesn't match, so we're done searching for previous date OR this date has no value in validationSet
                    #print("if10")
                    if maxHTP != -1: #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMaxHTP 
                        #case 1 - we're done with prev date
                        dateTimeMaxHTP[dOTPidx] = (prevDate,maxHTPTime,CallPut,sp,maxHTP)

                        #initialize variables for next iteration of dateWithOTP
                        dfStartIdx = index + 1
                        prevDate = row[0]
                        maxHTP = -1
                        break
    #PART 3 GETS minLTP
    dfStartIdx = 0
    #Date	TimeBarStart	Ticker	CallPut	Strike	ExpirationDate	OpenTradePrice	HighTradePrice	LowTradePrice	CloseTradePrice	
    dateTimeMinLTP = [(0,0,0,0,0) for _ in range(len(dateTimeMaxHTP))] #[date,time,CallPut,SP,minLTP]
    prevDate = dateTimeMaxHTP[0][0]
    N = len(validationSet)
    curDfLen = N
    for dTMidx, (date,maxHTPTime,CallPut,sp,_) in enumerate(dateTimeMaxHTP):

        while int(prevDate) < date:
            #if the row's date is not part of our dateTimeMaxHTP, then we keep moving to next row
            dfStartIdx += 1
            if dfStartIdx == N - 1:
                break
            prevDate = validationSet[dfStartIdx][0]


        #print("Checking for date={},maxHTPTime={},CallPut={},sp={}".format(date,maxHTPTime,CallPut,sp))
        minLTP = float("inf")
        doSameDate = False

        if maxHTPTime == "9:37:00 AM":
            #print("inside maxHTPTime == 9:37:00 AM")
            #if the max time occurs at 9:37:00 AM then find the minimum LowTradePrice of the option from 9:37:00 AM to the end of the day
            for index,row in enumerate(validationSet[dfStartIdx:],dfStartIdx):
                #print("index,dfStartIdx,N-dfStartIdx-1,time: {},{},{},{}".format(index,dfStartIdx,N-dfStartIdx-1,row[1]))
                #print("htp={},minLTP={},time={}".format(row[8],minLTP,row[1]))
                if index == N-1: #index == N - dfStartIdx - 2:
                    #case 1 - we're done with prev date
                    #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                    dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                    #initialize variables for next iteration of dateTimeMaxHTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    minLTP = float("inf")
                    break

                #want 9:37AM to end of day
                #otherwise toss out this row
                if beforeTime(row[1],"9:37:00 AM") or afterTime(row[1],"3:59:00 PM"):
                    if index == N-1: #index == N - dfStartIdx - 2:
                        #case 1 - we're done with prev date
                        #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                        dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                        #initialize variables for next iteration of dateTimeMaxHTP
                        dfStartIdx = index + 1
                        prevDate = row[0]
                        minLTP = float("inf")
                        break
                    continue
                elif date == row[0] and CallPut == row[3] and sp == row[4]:
                    #print("row: {}".format(list(row)))
                    #Check if there's a new max HTP
                    #print("htp={},minLTP={},time={}".format(row[8],minLTP,row[1]))
                    if row[8] < minLTP:
                        #print("update for minLTP: {}".format(row[8]))
                        minLTP = row[8]
                        minLTPTime = row[1]
                elif date != row[0]:
                    #date doesn't match, so we're done searching for previous date OR this date has no value in validationSet
                    if minLTP != float("inf"): #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMinLTP  
                        #case 1 - we're done with prev date
                        #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                        dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                        #initialize variables for next iteration of dateTimeMaxHTP
                        dfStartIdx = index + 1
                        prevDate = row[0]
                        minLTP = float("inf")
                        break
                    elif index == N-1: #index == N - dfStartIdx - 2:
                        #case 1 - we're done with prev date
                        #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                        dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                        #initialize variables for next iteration of dateTimeMaxHTP
                        dfStartIdx = index + 1
                        prevDate = row[0]
                        minLTP = float("inf")
                        break
                    else:
                        #print('if5 - date has no value in validationSet')
                        #Case 2 - date has no value in validationSet, so doesn't exist in dateTimeMaxHTP
                        #keep iterating until we past this date and until we found the date that matches dateTimeMaxHTP
                        dfStartIdx = index + 1
                        #print("dfStartIdx: {}".format(dfStartIdx))
                        for indexb,rowb in enumerate(validationSet[dfStartIdx:],dfStartIdx):
                            if rowb[0] == date:
                                prevDate = rowb[0]
                                dfStartIdx = indexb
                                doSameDate = True #found matching date so now iterate from that as startIdx to cover it instead of using current for loop
                                break
                        if doSameDate:
                            break


                if doSameDate:
                    for index,row in enumerate(validationSet[dfStartIdx:],dfStartIdx):
                        #print("index,dfStartIdx,N-dfStartIdx-1: {},{},{}".format(index,dfStartIdx,N-dfStartIdx-1))
                        if minLTP != float("inf"): #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMinLTP  
                            #case 1 - we're done with prev date
                            #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                            dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                            #initialize variables for next iteration of dateTimeMaxHTP
                            dfStartIdx = index + 1
                            prevDate = row[0]
                            minLTP = float("inf")
                            break

                        #want 9:37AM to end of day
                        #otherwise toss out this row
                        if beforeTime(row[1],"9:37:00 AM") or afterTime(row[1],"3:59:00 PM"):
                            if index == N-1: #N - dfStartIdx - 2: # 80352 - 41175 # - 1
                                #reached the last index in validationSet, so update for minLTP
                                #case 1 - we're done with prev date
                                #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                                dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                                #initialize variables for next iteration of dateTimeMaxHTP
                                dfStartIdx = index + 1
                                prevDate = row[0]
                                minLTP = float("inf")
                                break
                            continue
                        elif date == row[0] and CallPut == row[3] and sp == row[4]:
                            #print("row: {}".format(list(row)))
                            #Check if there's a new max HTP
                            #print("htp={},minLTP={},time={}".format(row[8],minLTP,row[1]))
                            if row[8] < minLTP:
                                #print("update for minLTP: {}".format(row[8]))
                                minLTP = row[8]
                                minLTPTime = row[1]
                        elif date != row[0]:
                            #date doesn't match, so we're done searching for previous date OR this date has no value in validationSet
                            if minLTP != float("inf"): #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMinLTP 
                                #case 1 - we're done with prev date
                                #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                                dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                                #initialize variables for next iteration of dateTimeMaxHTP
                                dfStartIdx = index + 1
                                prevDate = row[0]
                                minLTP = float("inf")
                                break
        else:
            #print("NOT inside maxHTPTime == 9:37:00 AM")
            #max occurs after 9:37AM - find the minimum of the option (LowTradePrice) from 9:37:00 AM to the max HTP time
            for index,row in enumerate(validationSet[dfStartIdx:],dfStartIdx):
                #print("index,dfStartIdx,N-dfStartIdx-1: {},{},{}".format(index,dfStartIdx,N-dfStartIdx-1))
                #print("htp={},minLTP={},time={}".format(row[8],minLTP,row[1]))
                if index == N-1: #index == N - dfStartIdx - 2:
                    #case 1 - we're done with prev date
                    #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                    dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                    #initialize variables for next iteration of dateTimeMaxHTP
                    dfStartIdx = index + 1
                    prevDate = row[0]
                    minLTP = float("inf")
                    break

                #want 9:37AM to maxHTP time
                #toss out others
                if beforeTime(row[1],"9:37:00 AM") or afterTime(row[1],maxHTPTime):
                    if index == N-1: #index == N - dfStartIdx - 2:
                        #case 1 - we're done with prev date
                        #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                        dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                        #initialize variables for next iteration of dateTimeMaxHTP
                        dfStartIdx = index + 1
                        prevDate = row[0]
                        minLTP = float("inf")
                        break
                    continue
                elif date == row[0] and CallPut == row[3] and sp == row[4]:
                    #print("row: {}".format(list(row)))
                    #Check if there's a new max HTP
                    #print("htp={},minLTP={},time={}".format(row[8],minLTP,row[1]))
                    if row[8] < minLTP:
                        #print("update for minLTP: {}".format(row[8]))
                        minLTP = row[8]
                        minLTPTime = row[1]
                elif date != row[0]:
                    #date doesn't match, so we're done searching for previous date OR this date has no value in validationSet
                    if minLTP != float("inf"): #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMinLTP  
                        #case 1 - we're done with prev date
                        #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                        dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                        #initialize variables for next iteration of dateTimeMaxHTP
                        dfStartIdx = index + 1
                        prevDate = row[0]
                        minLTP = float("inf")
                        break
                    elif index == N-1: #index == N - dfStartIdx - 2:
                        #case 1 - we're done with prev date
                        #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                        dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                        #initialize variables for next iteration of dateTimeMaxHTP
                        dfStartIdx = index + 1
                        prevDate = row[0]
                        minLTP = float("inf")
                        break
                    else:
                        #print('if5')
                        #Case 2 - date has no value in validationSet, so doesn't exist in dateTimeMaxHTP
                        #keep iterating until we past this date and until we found the date that matches dateTimeMaxHTP
                        dfStartIdx = index + 1
                        #print("dfStartIdx: {}".format(dfStartIdx))
                        for indexb,rowb in enumerate(validationSet[dfStartIdx:],dfStartIdx):
                            if rowb[0] == date:
                                prevDate = rowb[0]
                                dfStartIdx = indexb
                                doSameDate = True #found matching date so now iterate from that as startIdx to cover it instead of using current for loop
                                break
                        if doSameDate:
                            break


                if doSameDate:
                    for index,row in enumerate(validationSet[dfStartIdx:],dfStartIdx):
                        #print("index,dfStartIdx,N-dfStartIdx-1: {},{},{}".format(index,dfStartIdx,N-dfStartIdx-1))
                        if minLTP != float("inf"): #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMinLTP  
                            #case 1 - we're done with prev date
                            #print("prevDate={},CallPut={},sp={},minLTP={}".format(prevDate,CallPut,sp,minLTP))
                            #print("prevDate={},minLTPTime={},CallPut={},sp={},minLTP={}".format(prevDate,minLTPTime,CallPut,sp,minLTP))
                            dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                            #initialize variables for next iteration of dateTimeMaxHTP
                            dfStartIdx = index + 1
                            prevDate = row[0]
                            minLTP = float("inf")
                            break

                        if beforeTime(row[1],"9:37:00 AM") or afterTime(row[1],maxHTPTime):
                            if index == N-1: #N - dfStartIdx - 2: # 80352 - 41175 # - 1
                                #reached the last index in validationSet, so update for minLTP
                                #case 1 - we're done with prev date
                                dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                                #initialize variables for next iteration of dateTimeMaxHTP
                                dfStartIdx = index + 1
                                prevDate = row[0]
                                minLTP = float("inf")
                                break
                            continue
                        elif date == row[0] and CallPut == row[3] and sp == row[4]:
                            #print("row: {}".format(list(row)))
                            #Check if there's a new max HTP
                            #print("htp={},minLTP={},time={}".format(row[8],minLTP,row[1]))
                            if row[8] < minLTP:
                                #print("update for minLTP: {}".format(row[8]))
                                minLTP = row[8]
                                minLTPTime = row[1]
                        elif date != row[0]:
                            #date doesn't match, so we're done searching for previous date OR this date has no value in validationSet
                            if minLTP != float("inf"): #or index == N - dfStartIdx - 1: #the right of "or" represents last index, so we compute dateTimeMinLTP 
                                #case 1 - we're done with prev date
                                dateTimeMinLTP[dTMidx] = (prevDate,minLTPTime,CallPut,sp,minLTP)

                                #initialize variables for next iteration of dateTimeMaxHTP
                                dfStartIdx = index + 1
                                prevDate = row[0]
                                minLTP = float("inf")
                                break
    
    #MERGE ALL 4 PARTS
    #part 1 - dateTimeCandleSP = [] #(date,time,color,StrikePrice,StockPrice)
    #part 2 - dateWithOTP = [] #(date, time, CallPut, SP, OTP)
    #part 3 - dateTimeMinLTP = [(0,0,0,0,0) for _ in range(len(dateTimeMaxHTP))] #[date,time,CallPut,SP,minLTP]
    #part 4 - dateTimeMaxHTP = [(0,0,0,0,0) for _ in range(len(dateWithOTP))] #[date,time,CallPut,SP,maxHTP]
    numDates = len(dateTimeCandleSP)
    result = [("Z","Z",-1,-1,-1) for _ in range(numDates)] #(date,color,SP,OTP,minLTP,maxHTP)
    for index in range(numDates):
        date = dateTimeCandleSP[index][0]
        color = dateTimeCandleSP[index][2]
        SP = dateWithOTP[index][3]
        OTP = dateWithOTP[index][4]
        minLTP = dateTimeMinLTP[index][4]
        maxHTP = dateTimeMaxHTP[index][4]
        result[index] = (date,color,SP,OTP,minLTP,maxHTP)
    return result

# %%
#dfValidation = pd.read_csv('Jan 2020 - Dec 2020 merged SPY.csv')
result = datasetToMerged(validationSet)
result #(date,color,SP,OTP,minLTP,maxHTP)
# Out:
# [(20200228, 'GREEN', 293, 3.3, 1.17, 4.68),
#  (20200302, 'RED', 296, 2.69, 1.9, 3.75),
#  (20200304, 'RED', 305, 2.26, 2.22, 3.52),
#  (20200306, 'GREEN', 294, 2.87, 1.9, 5.15),
#  (20200311, 'GREEN', 282, 3.24, 0.01, 3.5)]

# %% [raw]
# #Using mostOccurredDropPerc, if the OTP drops by the mostOccurredDropPerc then we buy it and it becomes buyPriceGeneral
# #Now using the buyPriceGeneral, we see if the buyPriceGeneral*(1+mostOccuredBuyProfit) >= maxHTP, otherwise -50
#
# #Using the mostOccuredBuyProfit we need to look through the data again and see if the maxHTP reached that percentage,
# #if so, we profit that %, otherwise we would code it in is as -50% (which is our limit sell)
# #we then see the amount of situations we got correct and which ones we got wrong and see if the strategy is profitable
# #overall when used on a new set of data (validation set)

# %%
profits = [] #(date,profit)
printCount = 0 #for debug
#these are computed previously from a training dataset
#mostOccurredDropPerc:5
#mostOccuredBuyProfit:39

netProfit = 1
dfStartIdx = 0
#indices: 0=Date, 1=TimeBarStart, 13= UnderCloseAskPrice, 11=UnderOpenAskPrice
for date,color,SP,OTP,minLTP,maxHTP in result:
    print("Finding profit for date={}".format(date))
    #keep iterating row startIdx forward until we find matching date
    for index,row in enumerate(validationSet[dfStartIdx:],dfStartIdx):
        if row[0] != date:
            continue
        else:
            dfStartIdx = index
            break
    
    if color == "GREEN":
        callType = "C"
    else:
        callType = "P"
    
    #if our calculated price is > LTP then we successfully bought the option
    buyPrice = OTP * (1-mostOccurredDropPerc/100)
    bought = False
    for index,row in enumerate(validationSet[dfStartIdx:],dfStartIdx):
        #printCount += 1
        #if printCount % 10**4:
        #    print("date={},time={}".format(row[0],row[1]))
        #print("date={},time={}".format(row[0],row[1]))
        soldThisMinute = False
        if callType == row[3] and SP == row[4] and afterTime(row[1],"9:36:00 AM") and beforeTime(row[1],"4:00:00 PM"):
            if row[1] == "3:59:00 PM":
                #This is our last time of the date that we're considering, so if we boughtsomething, then sell it
                if bought:
                    #sell what we bought at OTP from 3:59:00 PM
                    profit = row[6]/buyPrice #currentTimeOTP/buyPrice
                    netProfit *= profit
                    profits.append((date,profit))
                    print("Sold at: date={}, profit={}, buyPrice={}, sellPrice={}".format(date,profit,buyPrice,row[6]))
                    #buyPrice --> OTP
                    #5 --> 11 #2.2
                    #11 --> 5 #0.45
                    #[1.3,0.9,1.2] 1.3*0.9*1.2*(0.5)^failcount*(mostOccuredBuyProfit)^successCount
                    #1.3,1.5,0.9,0.5^2,1.39^5
                    #1.3*1.5
                    soldThisMinute = True
                    
                #reinitialize variables for next date
                dfStartIdx = index
                print("1. done with date={}".format(row[0]))
                break
                
            #if this date doesn't have 3:59PM with the desired constraints, then we will pretend that we didn't buy previously
            elif afterTime(row[1],"3:59:00 PM"):
                dfStartIdx = index
                print("2. done with date={}".format(row[0]))
                break
            elif bought:
                #see if this is sellable (i.e. sellGoal < HTP)
                if sellGoal < row[7]:
                    #successfully sold at this price, so obtain the profit
                    #our profit % is mostOccuredBuyProfit, so tally the success
                    #successCount += 1
                    profit = 1+mostOccuredBuyProfit/100
                    netProfit *= profit
                    profits.append((date,profit))
                    print("Sold at profit: date={}, profit={}, boughtAt={}, soldAt={}, HTP={}".format(date,profit,buyPrice,sellGoal,row[7]))
                    bought = False
                    soldThisMinute = True
                elif buyPrice * 0.5 >= row[8]:
                    #we hit -50% limit, so sell it for that loss before we lose more
                    netProfit *= 0.5
                    profit = 0.5
                    profits.append((date,profit))
                    print("Sold at loss: date={}, profit={}, buyPrice={}, sellPrice={}, LTP={}".format(date,profit,buyPrice,buyPrice/2,row[8]))
                    bought = False
                    soldThisMinute = True
                #otherwise keep holding
            
            if not bought and not soldThisMinute:
                if buyPrice > row[8]: #buyprice > LTP then we successfully bought the option
                    print("buyPrice={},LTP={}".format(buyPrice,row[8]))
                    bought = True
                    print("bought at date={},time={}".format(date,row[1]))
                    #We now look to sell it for buyPrice*(1+mostOccuredBuyProfit)
                    sellGoal = buyPrice*(1+mostOccuredBuyProfit/100)
        #if we past the desired time, then end the day
        if afterTime(row[1],"3:59:00 PM"):
            #reinitialize variables for next date
            dfStartIdx = index
            print("1. done with date={}".format(row[0]))
            break
# Out:
# Finding profit for date=20200228
# buyPrice=2.64,LTP=2.54
# bought at date=20200228,time=9:44:00 AM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.3
# buyPrice=2.64,LTP=1.35
# bought at date=20200228,time=10:05:00 AM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.29
# buyPrice=2.64,LTP=1.31
# bought at date=20200228,time=10:49:00 AM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.29
# buyPrice=2.64,LTP=1.31
# bought at date=20200228,time=11:07:00 AM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.25
# buyPrice=2.64,LTP=1.17
# bought at date=20200228,time=11:09:00 AM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.22
# buyPrice=2.64,LTP=1.43
# bought at date=20200228,time=11:12:00 AM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.24
# buyPrice=2.64,LTP=1.41
# bought at date=20200228,time=11:15:00 AM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.31
# buyPrice=2.64,LTP=1.34
# bought at date=20200228,time=1:38:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.18
# buyPrice=2.64,LTP=1.09
# bought at date=20200228,time=1:41:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.18
# buyPrice=2.64,LTP=1.24
# bought at date=20200228,time=1:43:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.09
# buyPrice=2.64,LTP=0.9
# bought at date=20200228,time=1:45:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.97
# buyPrice=2.64,LTP=0.89
# bought at date=20200228,time=1:47:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.93
# buyPrice=2.64,LTP=0.99
# bought at date=20200228,time=1:49:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.95
# buyPrice=2.64,LTP=0.97
# bought at date=20200228,time=1:51:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.0
# buyPrice=2.64,LTP=0.86
# bought at date=20200228,time=1:53:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.85
# buyPrice=2.64,LTP=0.77
# bought at date=20200228,time=1:55:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.75
# buyPrice=2.64,LTP=0.89
# bought at date=20200228,time=1:57:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.77
# buyPrice=2.64,LTP=0.92
# bought at date=20200228,time=1:59:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.75
# buyPrice=2.64,LTP=0.68
# bought at date=20200228,time=2:01:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.74
# buyPrice=2.64,LTP=0.68
# bought at date=20200228,time=2:04:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.6
# buyPrice=2.64,LTP=0.62
# bought at date=20200228,time=2:06:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.6
# buyPrice=2.64,LTP=0.58
# bought at date=20200228,time=2:08:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.56
# buyPrice=2.64,LTP=0.64
# bought at date=20200228,time=2:10:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.69
# buyPrice=2.64,LTP=0.69
# bought at date=20200228,time=2:12:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.71
# buyPrice=2.64,LTP=0.77
# bought at date=20200228,time=2:14:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.67
# buyPrice=2.64,LTP=0.67
# bought at date=20200228,time=2:17:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.7
# buyPrice=2.64,LTP=0.74
# bought at date=20200228,time=2:20:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.74
# buyPrice=2.64,LTP=0.98
# bought at date=20200228,time=2:22:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.0
# buyPrice=2.64,LTP=0.85
# bought at date=20200228,time=2:24:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.81
# buyPrice=2.64,LTP=0.71
# bought at date=20200228,time=2:26:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.79
# buyPrice=2.64,LTP=0.81
# bought at date=20200228,time=2:28:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.78
# buyPrice=2.64,LTP=1.1
# bought at date=20200228,time=2:30:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.1
# buyPrice=2.64,LTP=1.3
# bought at date=20200228,time=2:32:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.2
# buyPrice=2.64,LTP=1.08
# bought at date=20200228,time=2:36:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.21
# buyPrice=2.64,LTP=1.43
# bought at date=20200228,time=2:38:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.17
# buyPrice=2.64,LTP=1.23
# bought at date=20200228,time=2:40:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.2
# buyPrice=2.64,LTP=1.34
# bought at date=20200228,time=2:57:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.28
# buyPrice=2.64,LTP=1.33
# bought at date=20200228,time=3:00:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.21
# buyPrice=2.64,LTP=1.04
# bought at date=20200228,time=3:02:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.02
# buyPrice=2.64,LTP=0.94
# bought at date=20200228,time=3:04:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.8
# buyPrice=2.64,LTP=0.83
# bought at date=20200228,time=3:06:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.98
# buyPrice=2.64,LTP=0.92
# bought at date=20200228,time=3:08:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.91
# buyPrice=2.64,LTP=0.81
# bought at date=20200228,time=3:10:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.83
# buyPrice=2.64,LTP=0.95
# bought at date=20200228,time=3:12:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.96
# buyPrice=2.64,LTP=0.9
# bought at date=20200228,time=3:15:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.23
# buyPrice=2.64,LTP=1.3
# bought at date=20200228,time=3:17:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.31
# buyPrice=2.64,LTP=1.32
# bought at date=20200228,time=3:19:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=1.19
# buyPrice=2.64,LTP=1.0
# bought at date=20200228,time=3:21:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.73
# buyPrice=2.64,LTP=0.78
# bought at date=20200228,time=3:23:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.76
# buyPrice=2.64,LTP=0.82
# bought at date=20200228,time=3:25:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.57
# buyPrice=2.64,LTP=0.5
# bought at date=20200228,time=3:27:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.5
# buyPrice=2.64,LTP=0.4
# bought at date=20200228,time=3:29:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.37
# buyPrice=2.64,LTP=0.46
# bought at date=20200228,time=3:31:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.51
# buyPrice=2.64,LTP=0.5
# bought at date=20200228,time=3:33:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.42
# buyPrice=2.64,LTP=0.37
# bought at date=20200228,time=3:35:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.39
# buyPrice=2.64,LTP=0.4
# bought at date=20200228,time=3:37:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.35
# buyPrice=2.64,LTP=0.29
# bought at date=20200228,time=3:40:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.23
# buyPrice=2.64,LTP=0.18
# bought at date=20200228,time=3:42:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.15
# buyPrice=2.64,LTP=0.13
# bought at date=20200228,time=3:44:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.13
# buyPrice=2.64,LTP=0.17
# bought at date=20200228,time=3:46:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.2
# buyPrice=2.64,LTP=0.2
# bought at date=20200228,time=3:48:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.2
# buyPrice=2.64,LTP=0.21
# bought at date=20200228,time=3:50:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.33
# buyPrice=2.64,LTP=0.27
# bought at date=20200228,time=3:52:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.21
# buyPrice=2.64,LTP=0.21
# bought at date=20200228,time=3:54:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.44
# buyPrice=2.64,LTP=0.65
# bought at date=20200228,time=3:56:00 PM
# Sold at loss: date=20200228, profit=0.5, buyPrice=2.64, sellPrice=1.32, LTP=0.6
# buyPrice=2.64,LTP=0.75
# bought at date=20200228,time=3:58:00 PM
# Sold at: date=20200228, profit=0.5227272727272727, buyPrice=2.64, sellPrice=1.38
# 1. done with date=20200228
# Finding profit for date=20200302
# buyPrice=2.152,LTP=1.9
# bought at date=20200302,time=9:45:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=1.04
# buyPrice=2.152,LTP=1.0
# bought at date=20200302,time=10:52:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.97
# buyPrice=2.152,LTP=0.96
# bought at date=20200302,time=10:54:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.98
# buyPrice=2.152,LTP=0.98
# bought at date=20200302,time=10:56:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=1.0
# buyPrice=2.152,LTP=1.13
# bought at date=20200302,time=10:58:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.8
# buyPrice=2.152,LTP=0.74
# bought at date=20200302,time=11:12:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.73
# buyPrice=2.152,LTP=0.69
# bought at date=20200302,time=11:14:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.62
# buyPrice=2.152,LTP=0.64
# bought at date=20200302,time=11:16:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.66
# buyPrice=2.152,LTP=0.72
# bought at date=20200302,time=11:18:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.72
# buyPrice=2.152,LTP=0.63
# bought at date=20200302,time=11:20:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.63
# buyPrice=2.152,LTP=0.63
# bought at date=20200302,time=11:22:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.59
# buyPrice=2.152,LTP=0.59
# bought at date=20200302,time=11:24:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.55
# buyPrice=2.152,LTP=0.57
# bought at date=20200302,time=11:27:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.52
# buyPrice=2.152,LTP=0.53
# bought at date=20200302,time=11:29:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.52
# buyPrice=2.152,LTP=0.5
# bought at date=20200302,time=11:31:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.51
# buyPrice=2.152,LTP=0.56
# bought at date=20200302,time=11:33:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.62
# buyPrice=2.152,LTP=0.6
# bought at date=20200302,time=11:35:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.55
# buyPrice=2.152,LTP=0.47
# bought at date=20200302,time=11:37:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.41
# buyPrice=2.152,LTP=0.38
# bought at date=20200302,time=11:39:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.4
# buyPrice=2.152,LTP=0.51
# bought at date=20200302,time=11:42:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.5
# buyPrice=2.152,LTP=0.43
# bought at date=20200302,time=11:44:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.44
# buyPrice=2.152,LTP=0.48
# bought at date=20200302,time=11:46:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.45
# buyPrice=2.152,LTP=0.44
# bought at date=20200302,time=11:48:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.42
# buyPrice=2.152,LTP=0.43
# bought at date=20200302,time=11:50:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.4
# buyPrice=2.152,LTP=0.36
# bought at date=20200302,time=11:52:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.31
# buyPrice=2.152,LTP=0.31
# bought at date=20200302,time=11:54:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.26
# buyPrice=2.152,LTP=0.27
# bought at date=20200302,time=11:56:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.28
# buyPrice=2.152,LTP=0.3
# bought at date=20200302,time=11:59:00 AM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.19
# buyPrice=2.152,LTP=0.18
# bought at date=20200302,time=1:01:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.21
# buyPrice=2.152,LTP=0.19
# bought at date=20200302,time=1:04:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.24
# buyPrice=2.152,LTP=0.27
# bought at date=20200302,time=1:06:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.26
# buyPrice=2.152,LTP=0.22
# bought at date=20200302,time=1:11:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.24
# buyPrice=2.152,LTP=0.25
# bought at date=20200302,time=1:16:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.26
# buyPrice=2.152,LTP=0.27
# bought at date=20200302,time=1:18:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.29
# buyPrice=2.152,LTP=0.3
# bought at date=20200302,time=1:20:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.3
# buyPrice=2.152,LTP=0.32
# bought at date=20200302,time=1:23:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.31
# buyPrice=2.152,LTP=0.3
# bought at date=20200302,time=1:25:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.33
# buyPrice=2.152,LTP=0.35
# bought at date=20200302,time=1:27:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.41
# buyPrice=2.152,LTP=0.41
# bought at date=20200302,time=1:29:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.35
# buyPrice=2.152,LTP=0.43
# bought at date=20200302,time=1:31:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.41
# buyPrice=2.152,LTP=0.42
# bought at date=20200302,time=1:33:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.37
# buyPrice=2.152,LTP=0.31
# bought at date=20200302,time=1:35:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.31
# buyPrice=2.152,LTP=0.26
# bought at date=20200302,time=1:37:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.25
# buyPrice=2.152,LTP=0.22
# bought at date=20200302,time=1:39:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.23
# buyPrice=2.152,LTP=0.22
# bought at date=20200302,time=1:41:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.24
# buyPrice=2.152,LTP=0.25
# bought at date=20200302,time=1:43:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.24
# buyPrice=2.152,LTP=0.22
# bought at date=20200302,time=1:45:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.23
# buyPrice=2.152,LTP=0.25
# bought at date=20200302,time=1:47:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.29
# buyPrice=2.152,LTP=0.29
# bought at date=20200302,time=1:49:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.29
# buyPrice=2.152,LTP=0.26
# bought at date=20200302,time=1:51:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.3
# buyPrice=2.152,LTP=0.37
# bought at date=20200302,time=1:53:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.36
# buyPrice=2.152,LTP=0.34
# bought at date=20200302,time=1:55:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.31
# buyPrice=2.152,LTP=0.26
# bought at date=20200302,time=1:57:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.23
# buyPrice=2.152,LTP=0.19
# bought at date=20200302,time=1:59:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.18
# buyPrice=2.152,LTP=0.19
# bought at date=20200302,time=2:01:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.19
# buyPrice=2.152,LTP=0.19
# bought at date=20200302,time=2:04:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.2
# buyPrice=2.152,LTP=0.21
# bought at date=20200302,time=2:06:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.14
# buyPrice=2.152,LTP=0.14
# bought at date=20200302,time=2:10:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.17
# buyPrice=2.152,LTP=0.17
# bought at date=20200302,time=2:12:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.16
# buyPrice=2.152,LTP=0.15
# bought at date=20200302,time=2:14:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.15
# buyPrice=2.152,LTP=0.19
# bought at date=20200302,time=2:16:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.18
# buyPrice=2.152,LTP=0.2
# bought at date=20200302,time=2:20:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.2
# buyPrice=2.152,LTP=0.2
# bought at date=20200302,time=2:24:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.24
# buyPrice=2.152,LTP=0.22
# bought at date=20200302,time=2:27:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.18
# buyPrice=2.152,LTP=0.25
# bought at date=20200302,time=2:29:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.24
# buyPrice=2.152,LTP=0.26
# bought at date=20200302,time=2:32:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.27
# buyPrice=2.152,LTP=0.25
# bought at date=20200302,time=2:34:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.31
# buyPrice=2.152,LTP=0.34
# bought at date=20200302,time=2:36:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.35
# buyPrice=2.152,LTP=0.4
# bought at date=20200302,time=2:38:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.41
# buyPrice=2.152,LTP=0.49
# bought at date=20200302,time=2:40:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.54
# buyPrice=2.152,LTP=0.55
# bought at date=20200302,time=2:42:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.68
# buyPrice=2.152,LTP=0.61
# bought at date=20200302,time=2:44:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.62
# buyPrice=2.152,LTP=0.51
# bought at date=20200302,time=2:46:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.41
# buyPrice=2.152,LTP=0.31
# bought at date=20200302,time=2:48:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.27
# buyPrice=2.152,LTP=0.3
# bought at date=20200302,time=2:50:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.34
# buyPrice=2.152,LTP=0.26
# bought at date=20200302,time=2:52:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.23
# buyPrice=2.152,LTP=0.23
# bought at date=20200302,time=2:54:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.22
# buyPrice=2.152,LTP=0.24
# bought at date=20200302,time=2:56:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.26
# buyPrice=2.152,LTP=0.31
# bought at date=20200302,time=2:58:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.36
# buyPrice=2.152,LTP=0.33
# bought at date=20200302,time=3:00:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.27
# buyPrice=2.152,LTP=0.2
# bought at date=20200302,time=3:02:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.2
# buyPrice=2.152,LTP=0.18
# bought at date=20200302,time=3:04:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.14
# buyPrice=2.152,LTP=0.13
# bought at date=20200302,time=3:06:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.13
# buyPrice=2.152,LTP=0.12
# bought at date=20200302,time=3:08:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.1
# buyPrice=2.152,LTP=0.11
# bought at date=20200302,time=3:10:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.11
# buyPrice=2.152,LTP=0.1
# bought at date=20200302,time=3:12:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.08
# buyPrice=2.152,LTP=0.08
# bought at date=20200302,time=3:14:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.11
# buyPrice=2.152,LTP=0.07
# bought at date=20200302,time=3:16:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.05
# buyPrice=2.152,LTP=0.07
# bought at date=20200302,time=3:18:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.06
# buyPrice=2.152,LTP=0.03
# bought at date=20200302,time=3:21:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.04
# buyPrice=2.152,LTP=0.04
# bought at date=20200302,time=3:23:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.03
# buyPrice=2.152,LTP=0.03
# bought at date=20200302,time=3:25:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.03
# buyPrice=2.152,LTP=0.02
# bought at date=20200302,time=3:27:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.03
# buyPrice=2.152,LTP=0.02
# bought at date=20200302,time=3:29:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.02
# buyPrice=2.152,LTP=0.02
# bought at date=20200302,time=3:32:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.02
# buyPrice=2.152,LTP=0.02
# bought at date=20200302,time=3:34:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.04
# buyPrice=2.152,LTP=0.02
# bought at date=20200302,time=3:36:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.01
# buyPrice=2.152,LTP=0.02
# bought at date=20200302,time=3:38:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.02
# buyPrice=2.152,LTP=0.01
# bought at date=20200302,time=3:40:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.01
# buyPrice=2.152,LTP=0.01
# bought at date=20200302,time=3:43:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.01
# buyPrice=2.152,LTP=0.01
# bought at date=20200302,time=3:45:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.01
# buyPrice=2.152,LTP=0.01
# bought at date=20200302,time=3:49:00 PM
# Sold at loss: date=20200302, profit=0.5, buyPrice=2.152, sellPrice=1.076, LTP=0.01
# 1. done with date=20200302
# Finding profit for date=20200304
# buyPrice=1.8079999999999998,LTP=1.68
# bought at date=20200304,time=10:17:00 AM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.54
# buyPrice=1.8079999999999998,LTP=0.57
# bought at date=20200304,time=1:01:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.59
# buyPrice=1.8079999999999998,LTP=0.55
# bought at date=20200304,time=1:03:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.53
# buyPrice=1.8079999999999998,LTP=0.48
# bought at date=20200304,time=1:05:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.5
# buyPrice=1.8079999999999998,LTP=0.5
# bought at date=20200304,time=1:07:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.54
# buyPrice=1.8079999999999998,LTP=0.54
# bought at date=20200304,time=1:09:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.6
# buyPrice=1.8079999999999998,LTP=0.54
# bought at date=20200304,time=1:11:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.55
# buyPrice=1.8079999999999998,LTP=0.55
# bought at date=20200304,time=1:13:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.52
# buyPrice=1.8079999999999998,LTP=0.48
# bought at date=20200304,time=1:15:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.46
# buyPrice=1.8079999999999998,LTP=0.45
# bought at date=20200304,time=1:17:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.45
# buyPrice=1.8079999999999998,LTP=0.38
# bought at date=20200304,time=1:19:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.37
# buyPrice=1.8079999999999998,LTP=0.37
# bought at date=20200304,time=1:21:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.37
# buyPrice=1.8079999999999998,LTP=0.36
# bought at date=20200304,time=1:23:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.35
# buyPrice=1.8079999999999998,LTP=0.35
# bought at date=20200304,time=1:25:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.38
# buyPrice=1.8079999999999998,LTP=0.42
# bought at date=20200304,time=1:27:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.39
# buyPrice=1.8079999999999998,LTP=0.4
# bought at date=20200304,time=1:29:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.38
# buyPrice=1.8079999999999998,LTP=0.35
# bought at date=20200304,time=1:31:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.36
# buyPrice=1.8079999999999998,LTP=0.34
# bought at date=20200304,time=1:33:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.34
# buyPrice=1.8079999999999998,LTP=0.32
# bought at date=20200304,time=1:35:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.35
# buyPrice=1.8079999999999998,LTP=0.32
# bought at date=20200304,time=1:37:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.32
# buyPrice=1.8079999999999998,LTP=0.34
# bought at date=20200304,time=1:39:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.35
# buyPrice=1.8079999999999998,LTP=0.35
# bought at date=20200304,time=1:41:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.37
# buyPrice=1.8079999999999998,LTP=0.38
# bought at date=20200304,time=1:43:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.36
# buyPrice=1.8079999999999998,LTP=0.37
# bought at date=20200304,time=1:45:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.38
# buyPrice=1.8079999999999998,LTP=0.37
# bought at date=20200304,time=1:47:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.34
# buyPrice=1.8079999999999998,LTP=0.31
# bought at date=20200304,time=1:49:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.3
# buyPrice=1.8079999999999998,LTP=0.28
# bought at date=20200304,time=1:51:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.28
# buyPrice=1.8079999999999998,LTP=0.28
# bought at date=20200304,time=1:53:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.28
# buyPrice=1.8079999999999998,LTP=0.3
# bought at date=20200304,time=1:55:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.32
# buyPrice=1.8079999999999998,LTP=0.3
# bought at date=20200304,time=1:57:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.33
# buyPrice=1.8079999999999998,LTP=0.32
# bought at date=20200304,time=1:59:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.28
# buyPrice=1.8079999999999998,LTP=0.33
# bought at date=20200304,time=2:01:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.37
# buyPrice=1.8079999999999998,LTP=0.39
# bought at date=20200304,time=2:03:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.37
# buyPrice=1.8079999999999998,LTP=0.4
# bought at date=20200304,time=2:05:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.39
# buyPrice=1.8079999999999998,LTP=0.34
# bought at date=20200304,time=2:07:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.35
# buyPrice=1.8079999999999998,LTP=0.35
# bought at date=20200304,time=2:09:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.31
# buyPrice=1.8079999999999998,LTP=0.29
# bought at date=20200304,time=2:11:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.31
# buyPrice=1.8079999999999998,LTP=0.31
# bought at date=20200304,time=2:13:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.32
# buyPrice=1.8079999999999998,LTP=0.34
# bought at date=20200304,time=2:15:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.3
# buyPrice=1.8079999999999998,LTP=0.29
# bought at date=20200304,time=2:17:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.25
# buyPrice=1.8079999999999998,LTP=0.26
# bought at date=20200304,time=2:19:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.26
# buyPrice=1.8079999999999998,LTP=0.25
# bought at date=20200304,time=2:21:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.25
# buyPrice=1.8079999999999998,LTP=0.26
# bought at date=20200304,time=2:23:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.25
# buyPrice=1.8079999999999998,LTP=0.22
# bought at date=20200304,time=2:25:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.18
# buyPrice=1.8079999999999998,LTP=0.19
# bought at date=20200304,time=2:27:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.19
# buyPrice=1.8079999999999998,LTP=0.19
# bought at date=20200304,time=2:29:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.18
# buyPrice=1.8079999999999998,LTP=0.18
# bought at date=20200304,time=2:31:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.17
# buyPrice=1.8079999999999998,LTP=0.18
# bought at date=20200304,time=2:33:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.18
# buyPrice=1.8079999999999998,LTP=0.19
# bought at date=20200304,time=2:35:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.19
# buyPrice=1.8079999999999998,LTP=0.2
# bought at date=20200304,time=2:37:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.21
# buyPrice=1.8079999999999998,LTP=0.23
# bought at date=20200304,time=2:39:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.22
# buyPrice=1.8079999999999998,LTP=0.24
# bought at date=20200304,time=2:41:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.22
# buyPrice=1.8079999999999998,LTP=0.19
# bought at date=20200304,time=2:43:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.2
# buyPrice=1.8079999999999998,LTP=0.21
# bought at date=20200304,time=2:45:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.21
# buyPrice=1.8079999999999998,LTP=0.21
# bought at date=20200304,time=2:47:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.21
# buyPrice=1.8079999999999998,LTP=0.23
# bought at date=20200304,time=2:49:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.22
# buyPrice=1.8079999999999998,LTP=0.26
# bought at date=20200304,time=2:51:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.29
# buyPrice=1.8079999999999998,LTP=0.23
# bought at date=20200304,time=2:53:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.24
# buyPrice=1.8079999999999998,LTP=0.23
# bought at date=20200304,time=2:55:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.21
# buyPrice=1.8079999999999998,LTP=0.19
# bought at date=20200304,time=2:58:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.21
# buyPrice=1.8079999999999998,LTP=0.21
# bought at date=20200304,time=3:00:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.19
# buyPrice=1.8079999999999998,LTP=0.18
# bought at date=20200304,time=3:02:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.17
# buyPrice=1.8079999999999998,LTP=0.17
# bought at date=20200304,time=3:04:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.15
# buyPrice=1.8079999999999998,LTP=0.13
# bought at date=20200304,time=3:06:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.15
# buyPrice=1.8079999999999998,LTP=0.19
# bought at date=20200304,time=3:08:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.15
# buyPrice=1.8079999999999998,LTP=0.14
# bought at date=20200304,time=3:10:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.13
# buyPrice=1.8079999999999998,LTP=0.1
# bought at date=20200304,time=3:12:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.08
# buyPrice=1.8079999999999998,LTP=0.09
# bought at date=20200304,time=3:14:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.09
# buyPrice=1.8079999999999998,LTP=0.09
# bought at date=20200304,time=3:17:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.08
# buyPrice=1.8079999999999998,LTP=0.07
# bought at date=20200304,time=3:19:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.06
# buyPrice=1.8079999999999998,LTP=0.06
# bought at date=20200304,time=3:21:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.04
# buyPrice=1.8079999999999998,LTP=0.04
# bought at date=20200304,time=3:23:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.03
# buyPrice=1.8079999999999998,LTP=0.04
# bought at date=20200304,time=3:25:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.03
# buyPrice=1.8079999999999998,LTP=0.04
# bought at date=20200304,time=3:27:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.03
# buyPrice=1.8079999999999998,LTP=0.02
# bought at date=20200304,time=3:30:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.02
# buyPrice=1.8079999999999998,LTP=0.02
# bought at date=20200304,time=3:33:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.01
# buyPrice=1.8079999999999998,LTP=0.01
# bought at date=20200304,time=3:35:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.01
# buyPrice=1.8079999999999998,LTP=0.01
# bought at date=20200304,time=3:37:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.01
# buyPrice=1.8079999999999998,LTP=0.02
# bought at date=20200304,time=3:39:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.01
# buyPrice=1.8079999999999998,LTP=0.01
# bought at date=20200304,time=3:41:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.01
# buyPrice=1.8079999999999998,LTP=0.02
# bought at date=20200304,time=3:43:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.02
# buyPrice=1.8079999999999998,LTP=0.01
# bought at date=20200304,time=3:45:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.01
# buyPrice=1.8079999999999998,LTP=0.02
# bought at date=20200304,time=3:50:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.01
# buyPrice=1.8079999999999998,LTP=0.01
# bought at date=20200304,time=3:52:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.01
# buyPrice=1.8079999999999998,LTP=0.01
# bought at date=20200304,time=3:55:00 PM
# Sold at loss: date=20200304, profit=0.5, buyPrice=1.8079999999999998, sellPrice=0.9039999999999999, LTP=0.01
# buyPrice=1.8079999999999998,LTP=0.01
# bought at date=20200304,time=3:58:00 PM
# Sold at profit: date=20200304, profit=1.8399999999999999, boughtAt=1.8079999999999998, soldAt=3.3267199999999995, HTP=11.06
# 1. done with date=20200306
# Finding profit for date=20200306
# 1. done with date=20200306
# Finding profit for date=20200311
# buyPrice=2.5920000000000005,LTP=2.55
# bought at date=20200311,time=9:39:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.25
# buyPrice=2.5920000000000005,LTP=1.28
# bought at date=20200311,time=10:50:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.25
# buyPrice=2.5920000000000005,LTP=1.22
# bought at date=20200311,time=10:52:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.2
# buyPrice=2.5920000000000005,LTP=1.23
# bought at date=20200311,time=10:54:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.24
# buyPrice=2.5920000000000005,LTP=1.13
# bought at date=20200311,time=10:56:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.12
# buyPrice=2.5920000000000005,LTP=1.08
# bought at date=20200311,time=10:58:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.27
# buyPrice=2.5920000000000005,LTP=1.37
# bought at date=20200311,time=11:00:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.28
# buyPrice=2.5920000000000005,LTP=1.3
# bought at date=20200311,time=11:05:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.26
# buyPrice=2.5920000000000005,LTP=1.28
# bought at date=20200311,time=11:07:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.24
# buyPrice=2.5920000000000005,LTP=1.19
# bought at date=20200311,time=11:09:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.25
# buyPrice=2.5920000000000005,LTP=1.26
# bought at date=20200311,time=11:17:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.07
# buyPrice=2.5920000000000005,LTP=1.05
# bought at date=20200311,time=11:20:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.01
# buyPrice=2.5920000000000005,LTP=1.0
# bought at date=20200311,time=11:22:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.0
# buyPrice=2.5920000000000005,LTP=0.94
# bought at date=20200311,time=11:24:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.94
# buyPrice=2.5920000000000005,LTP=1.0
# bought at date=20200311,time=11:26:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.98
# buyPrice=2.5920000000000005,LTP=1.0
# bought at date=20200311,time=11:28:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.98
# buyPrice=2.5920000000000005,LTP=0.99
# bought at date=20200311,time=11:30:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.94
# buyPrice=2.5920000000000005,LTP=1.0
# bought at date=20200311,time=11:32:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.12
# buyPrice=2.5920000000000005,LTP=1.14
# bought at date=20200311,time=11:34:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.1
# buyPrice=2.5920000000000005,LTP=1.13
# bought at date=20200311,time=11:36:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.23
# buyPrice=2.5920000000000005,LTP=1.28
# bought at date=20200311,time=11:38:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.26
# buyPrice=2.5920000000000005,LTP=1.31
# bought at date=20200311,time=11:40:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.21
# buyPrice=2.5920000000000005,LTP=1.12
# bought at date=20200311,time=11:42:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.1
# buyPrice=2.5920000000000005,LTP=1.11
# bought at date=20200311,time=11:44:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.1
# buyPrice=2.5920000000000005,LTP=0.92
# bought at date=20200311,time=11:46:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.94
# buyPrice=2.5920000000000005,LTP=1.02
# bought at date=20200311,time=11:48:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.18
# buyPrice=2.5920000000000005,LTP=1.17
# bought at date=20200311,time=11:50:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.08
# buyPrice=2.5920000000000005,LTP=1.02
# bought at date=20200311,time=11:52:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.1
# buyPrice=2.5920000000000005,LTP=0.98
# bought at date=20200311,time=11:55:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.0
# buyPrice=2.5920000000000005,LTP=1.02
# bought at date=20200311,time=11:58:00 AM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=1.17
# buyPrice=2.5920000000000005,LTP=0.65
# bought at date=20200311,time=1:00:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.63
# buyPrice=2.5920000000000005,LTP=0.61
# bought at date=20200311,time=1:02:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.56
# buyPrice=2.5920000000000005,LTP=0.55
# bought at date=20200311,time=1:04:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.55
# buyPrice=2.5920000000000005,LTP=0.51
# bought at date=20200311,time=1:06:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.57
# buyPrice=2.5920000000000005,LTP=0.51
# bought at date=20200311,time=1:08:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.54
# buyPrice=2.5920000000000005,LTP=0.51
# bought at date=20200311,time=1:10:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.53
# buyPrice=2.5920000000000005,LTP=0.52
# bought at date=20200311,time=1:12:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.55
# buyPrice=2.5920000000000005,LTP=0.55
# bought at date=20200311,time=1:14:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.56
# buyPrice=2.5920000000000005,LTP=0.65
# bought at date=20200311,time=1:16:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.6
# buyPrice=2.5920000000000005,LTP=0.61
# bought at date=20200311,time=1:18:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.62
# buyPrice=2.5920000000000005,LTP=0.69
# bought at date=20200311,time=1:20:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.7
# buyPrice=2.5920000000000005,LTP=0.7
# bought at date=20200311,time=1:22:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.58
# buyPrice=2.5920000000000005,LTP=0.6
# bought at date=20200311,time=1:24:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.58
# buyPrice=2.5920000000000005,LTP=0.74
# bought at date=20200311,time=1:26:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.71
# buyPrice=2.5920000000000005,LTP=0.71
# bought at date=20200311,time=1:28:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.73
# buyPrice=2.5920000000000005,LTP=0.81
# bought at date=20200311,time=1:31:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.71
# buyPrice=2.5920000000000005,LTP=0.66
# bought at date=20200311,time=1:33:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.63
# buyPrice=2.5920000000000005,LTP=0.55
# bought at date=20200311,time=1:36:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.55
# buyPrice=2.5920000000000005,LTP=0.55
# bought at date=20200311,time=1:39:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.52
# buyPrice=2.5920000000000005,LTP=0.5
# bought at date=20200311,time=1:41:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.42
# buyPrice=2.5920000000000005,LTP=0.45
# bought at date=20200311,time=1:43:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.41
# buyPrice=2.5920000000000005,LTP=0.4
# bought at date=20200311,time=1:45:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.44
# buyPrice=2.5920000000000005,LTP=0.55
# bought at date=20200311,time=1:47:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.53
# buyPrice=2.5920000000000005,LTP=0.6
# bought at date=20200311,time=1:49:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.53
# buyPrice=2.5920000000000005,LTP=0.46
# bought at date=20200311,time=1:51:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.48
# buyPrice=2.5920000000000005,LTP=0.45
# bought at date=20200311,time=1:53:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.44
# buyPrice=2.5920000000000005,LTP=0.54
# bought at date=20200311,time=1:55:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.6
# buyPrice=2.5920000000000005,LTP=0.57
# bought at date=20200311,time=1:57:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.52
# buyPrice=2.5920000000000005,LTP=0.54
# bought at date=20200311,time=1:59:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.48
# buyPrice=2.5920000000000005,LTP=0.43
# bought at date=20200311,time=2:02:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.39
# buyPrice=2.5920000000000005,LTP=0.37
# bought at date=20200311,time=2:04:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.36
# buyPrice=2.5920000000000005,LTP=0.45
# bought at date=20200311,time=2:06:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.31
# buyPrice=2.5920000000000005,LTP=0.31
# bought at date=20200311,time=2:09:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.31
# buyPrice=2.5920000000000005,LTP=0.35
# bought at date=20200311,time=2:11:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.31
# buyPrice=2.5920000000000005,LTP=0.33
# bought at date=20200311,time=2:13:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.32
# buyPrice=2.5920000000000005,LTP=0.33
# bought at date=20200311,time=2:15:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.33
# buyPrice=2.5920000000000005,LTP=0.31
# bought at date=20200311,time=2:17:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.31
# buyPrice=2.5920000000000005,LTP=0.3
# bought at date=20200311,time=2:19:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.31
# buyPrice=2.5920000000000005,LTP=0.29
# bought at date=20200311,time=2:21:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.28
# buyPrice=2.5920000000000005,LTP=0.28
# bought at date=20200311,time=2:23:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.25
# buyPrice=2.5920000000000005,LTP=0.26
# bought at date=20200311,time=2:25:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.25
# buyPrice=2.5920000000000005,LTP=0.24
# bought at date=20200311,time=2:27:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.26
# buyPrice=2.5920000000000005,LTP=0.25
# bought at date=20200311,time=2:29:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.25
# buyPrice=2.5920000000000005,LTP=0.25
# bought at date=20200311,time=2:31:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.28
# buyPrice=2.5920000000000005,LTP=0.28
# bought at date=20200311,time=2:33:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.25
# buyPrice=2.5920000000000005,LTP=0.23
# bought at date=20200311,time=2:35:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.24
# buyPrice=2.5920000000000005,LTP=0.23
# bought at date=20200311,time=2:37:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.23
# buyPrice=2.5920000000000005,LTP=0.28
# bought at date=20200311,time=2:39:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.29
# buyPrice=2.5920000000000005,LTP=0.3
# bought at date=20200311,time=2:41:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.29
# buyPrice=2.5920000000000005,LTP=0.26
# bought at date=20200311,time=2:43:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.23
# buyPrice=2.5920000000000005,LTP=0.23
# bought at date=20200311,time=2:45:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.27
# buyPrice=2.5920000000000005,LTP=0.24
# bought at date=20200311,time=2:47:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.22
# buyPrice=2.5920000000000005,LTP=0.21
# bought at date=20200311,time=2:49:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.22
# buyPrice=2.5920000000000005,LTP=0.22
# bought at date=20200311,time=2:51:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.21
# buyPrice=2.5920000000000005,LTP=0.2
# bought at date=20200311,time=2:53:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.16
# buyPrice=2.5920000000000005,LTP=0.19
# bought at date=20200311,time=2:55:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.19
# buyPrice=2.5920000000000005,LTP=0.2
# bought at date=20200311,time=2:57:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.17
# buyPrice=2.5920000000000005,LTP=0.16
# bought at date=20200311,time=3:00:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.16
# buyPrice=2.5920000000000005,LTP=0.15
# bought at date=20200311,time=3:02:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.12
# buyPrice=2.5920000000000005,LTP=0.11
# bought at date=20200311,time=3:04:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.1
# buyPrice=2.5920000000000005,LTP=0.09
# bought at date=20200311,time=3:06:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.08
# buyPrice=2.5920000000000005,LTP=0.08
# bought at date=20200311,time=3:08:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.08
# buyPrice=2.5920000000000005,LTP=0.09
# bought at date=20200311,time=3:10:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.08
# buyPrice=2.5920000000000005,LTP=0.07
# bought at date=20200311,time=3:12:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.08
# buyPrice=2.5920000000000005,LTP=0.08
# bought at date=20200311,time=3:15:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.07
# buyPrice=2.5920000000000005,LTP=0.1
# bought at date=20200311,time=3:17:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.09
# buyPrice=2.5920000000000005,LTP=0.08
# bought at date=20200311,time=3:20:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.07
# buyPrice=2.5920000000000005,LTP=0.08
# bought at date=20200311,time=3:22:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.06
# buyPrice=2.5920000000000005,LTP=0.04
# bought at date=20200311,time=3:24:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.04
# buyPrice=2.5920000000000005,LTP=0.05
# bought at date=20200311,time=3:26:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.05
# buyPrice=2.5920000000000005,LTP=0.05
# bought at date=20200311,time=3:28:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.1
# buyPrice=2.5920000000000005,LTP=0.09
# bought at date=20200311,time=3:30:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.08
# buyPrice=2.5920000000000005,LTP=0.12
# bought at date=20200311,time=3:32:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.15
# buyPrice=2.5920000000000005,LTP=0.21
# bought at date=20200311,time=3:34:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.14
# buyPrice=2.5920000000000005,LTP=0.15
# bought at date=20200311,time=3:36:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.16
# buyPrice=2.5920000000000005,LTP=0.17
# bought at date=20200311,time=3:38:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.21
# buyPrice=2.5920000000000005,LTP=0.17
# bought at date=20200311,time=3:40:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.2
# buyPrice=2.5920000000000005,LTP=0.19
# bought at date=20200311,time=3:42:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.12
# buyPrice=2.5920000000000005,LTP=0.11
# bought at date=20200311,time=3:44:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.09
# buyPrice=2.5920000000000005,LTP=0.05
# bought at date=20200311,time=3:46:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.04
# buyPrice=2.5920000000000005,LTP=0.06
# bought at date=20200311,time=3:48:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.07
# buyPrice=2.5920000000000005,LTP=0.03
# bought at date=20200311,time=3:50:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.03
# buyPrice=2.5920000000000005,LTP=0.03
# bought at date=20200311,time=3:52:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.08
# buyPrice=2.5920000000000005,LTP=0.08
# bought at date=20200311,time=3:54:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.05
# buyPrice=2.5920000000000005,LTP=0.03
# bought at date=20200311,time=3:56:00 PM
# Sold at loss: date=20200311, profit=0.5, buyPrice=2.5920000000000005, sellPrice=1.2960000000000003, LTP=0.03
# buyPrice=2.5920000000000005,LTP=0.02
# bought at date=20200311,time=3:58:00 PM
# Sold at: date=20200311, profit=0.007716049382716048, buyPrice=2.5920000000000005, sellPrice=0.02
# 1. done with date=20200311

# %%
profits
# Out:
# [(20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5),
#  (20200228, 0.5227272727272727),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200302, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 0.5),
#  (20200304, 1.8399999999999999),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.5),
#  (20200311, 0.007716049382716048)]

# %%
mostOccurredDropPerc
mostOccuredBuyProfit
# Out:
# 84

# %%
netProfit
# Out:
# 2.4687639802586533e-113

# %% [raw]
# Things to try next time:
# 1) Try using a larger training dataset
# 2) Change the acceptable loss amount for limit loss sell (i.e. change 0.5 to something else)
# 3) Try out different values of mostOccurredDropPerc,mostOccuredBuyProfit
#
#
# #ctrlF comeback1
# #Make the df smaller (i.e. for each date, delete rows that aren't the same CallPut and StrikePrice)
# #Also delete the times that are >= 4:00:00 PM
#
# #(DONE) 04-23-2023 Need to fix [0,0,0,0,0] for last date in dateTimeMaxHTP
