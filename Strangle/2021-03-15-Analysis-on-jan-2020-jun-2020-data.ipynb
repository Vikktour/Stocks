# %%
import pandas as pd
import numpy as np
import math
#df = pd.read_csv(r'C:\Users\momoh\Desktop\Excel merged files\Jan 2020 - Dec 2020 merged SPY.csv')
df = pd.read_csv('Jan 2020 - Dec 2020 merged SPY.csv')
#df = pd.read_csv(r'C:\Users\momoh\Desktop\Excel merged files\Jan 2020 - Dec 2020 merged SPY.csv',header = None, names=["Date","TimeBarStart","Ticker","CallPut","Strike","ExpirationDate","OpenTradePrice","HighTradePrice","LowTradePrice","CloseTradePrice","UnderOpenBidPrice","UnderOpenAskPrice","UnderCloseBidPrice","UnderCloseAskPrice","VWAP","Volume","TotalTrades"], skiprows =1)
#df = pd.read_excel('Jan 2020 - Dec 2020 merged SPY.xlsb', engine='pyxlsb')
#df

# %%
#df.to_csv("new.csv", index = False) creates a new csv with the new info

# %%
column_values = df["Date"].values.ravel()
unique_values = pd.unique(column_values)
#print(unique_values)

# %%
df_unique = pd.DataFrame(unique_values, columns = ['Given Dates'])
df = pd.concat([df,df_unique], axis = 1)
df
# Out:
#              Date TimeBarStart Ticker CallPut  Strike  ExpirationDate  \
# 0        20200103   9:30:00 AM    SPY       P   320.5        20200103
# 1        20200103   9:30:00 AM    SPY       P   305.0        20200103
# 2        20200103   9:30:00 AM    SPY       P   317.0        20200103
# 3        20200103   9:30:00 AM    SPY       P   313.0        20200103
# 4        20200103   9:30:00 AM    SPY       P   321.5        20200103
# ...           ...          ...    ...     ...     ...             ...
# 1041992  20200630   4:14:00 PM    SPY       C   302.0        20200630
# 1041993  20200630   4:14:00 PM    SPY       C   305.0        20200630
# 1041994  20200630   4:14:00 PM    SPY       C   304.0        20200630
# 1041995  20200630   4:14:00 PM    SPY       C   307.0        20200630
# 1041996  20200630   4:14:00 PM    SPY       C   306.0        20200630
#
#          OpenTradePrice  HighTradePrice  LowTradePrice  CloseTradePrice  \
# 0                  0.57            0.60           0.47             0.47
# 1                  0.01            0.01           0.01             0.01
# 2                  0.12            0.12           0.10             0.10
# 3                  0.02            0.02           0.02             0.02
# 4                  0.98            0.98           0.82             0.82
# ...                 ...             ...            ...              ...
# 1041992            6.44            6.44           6.44             6.44
# 1041993            3.48            3.48           3.48             3.48
# 1041994            4.48            4.48           4.48             4.48
# 1041995            1.50            1.50           1.50             1.50
# 1041996            2.51            2.57           2.51             2.57
#
#          UnderOpenBidPrice  UnderOpenAskPrice  UnderCloseBidPrice  \
# 0                   321.13             321.15              321.55
# 1                   321.13             321.16              321.13
# 2                   321.18             321.20              321.33
# 3                   321.44             321.45              321.44
# 4                   321.14             321.16              321.47
# ...                    ...                ...                 ...
# 1041992             308.44             308.47              308.44
# 1041993             308.47             308.48              308.45
# 1041994             308.45             308.46              308.45
# 1041995             308.45             308.49              308.45
# 1041996             308.50             308.54              308.50
#
#          UnderCloseAskPrice    VWAP  Volume  TotalTrades  Given Dates
# 0                    321.56  0.5865     241           17   20200103.0
# 1                    321.16  0.0100       6            1   20200106.0
# 2                    321.34  0.1018      11            2   20200108.0
# 3                    321.45  0.0200       1            1   20200110.0
# 4                    321.48  0.9241     279           43   20200113.0
# ...                     ...     ...     ...          ...          ...
# 1041992              308.47  6.4400       6            1          NaN
# 1041993              308.48  3.4800       6            2          NaN
# 1041994              308.46  4.4800       1            1          NaN
# 1041995              308.49  1.5000       1            1          NaN
# 1041996              308.53  2.5400       2            2          NaN
#
# [1041997 rows x 18 columns]

# %%
df1 = df[['Date','TimeBarStart','CallPut','Strike', 'OpenTradePrice','HighTradePrice', 'LowTradePrice','UnderCloseAskPrice']]
print(df1)
# Out:
#              Date TimeBarStart CallPut  Strike  OpenTradePrice  \
# 0        20200103   9:30:00 AM       P   320.5            0.57
# 1        20200103   9:30:00 AM       P   305.0            0.01
# 2        20200103   9:30:00 AM       P   317.0            0.12
# 3        20200103   9:30:00 AM       P   313.0            0.02
# 4        20200103   9:30:00 AM       P   321.5            0.98
# ...           ...          ...     ...     ...             ...
# 1041992  20200630   4:14:00 PM       C   302.0            6.44
# 1041993  20200630   4:14:00 PM       C   305.0            3.48
# 1041994  20200630   4:14:00 PM       C   304.0            4.48
# 1041995  20200630   4:14:00 PM       C   307.0            1.50
# 1041996  20200630   4:14:00 PM       C   306.0            2.51
#
#          HighTradePrice  LowTradePrice  UnderCloseAskPrice
# 0                  0.60           0.47              321.56
# 1                  0.01           0.01              321.16
# 2                  0.12           0.10              321.34
# 3                  0.02           0.02              321.45
# 4                  0.98           0.82              321.48
# ...                 ...            ...                 ...
# 1041992            6.44           6.44              308.47
# 1041993            3.48           3.48              308.48
# 1041994            4.48           4.48              308.46
# 1041995            1.50           1.50              308.49
# 1041996            2.57           2.51              308.53
#
# [1041997 rows x 8 columns]

# %% [markdown]
# # The max value of the stock price at a given date and 9:45am

# %%
currentDate = df1['Date'][0]
currentTime = df1['TimeBarStart'][0]
rows = df1.loc[(df1['Date'] == currentDate) & (df1['TimeBarStart'] == currentTime)]
#print("rows: {}".format(rows))
maxUnderCloseAskPrice = max(rows['UnderCloseAskPrice'])
print(maxUnderCloseAskPrice)
# Out:
# 321.64

# %% [markdown]
# # Convert Date Time to the Max Under Close Ask Price

# %%
#takes in Date & Time, outputs Max Under Close Ask Price
def dateTimeToMaxUnderCloseAskPrice(date:int,time:str) -> int:
    rows = df1.loc[(df1['Date'] == date) & (df1['TimeBarStart'] == time)]
    #print("rows: {}".format(rows))
    if rows['UnderCloseAskPrice'].empty:
        return -1
    maxUnderCloseAskPrice = max(rows['UnderCloseAskPrice'])
    
    
    #print(maxUnderCloseAskPrice)
    return maxUnderCloseAskPrice

# %%
#Sample singular input
MUCAP = dateTimeToMaxUnderCloseAskPrice(20200630,"4:14:00 PM")
print(MUCAP)
# Out:
# 308.55

# %% [markdown]
# # This finds the strike price for the call and put at given date and time

# %%
#print("unique_values: {}".format(unique_values))
dates = unique_values
time = "9:45:00 AM"

printCount = 0
for date in dates:
    #print("date={}".format(date))
    MUCAP = dateTimeToMaxUnderCloseAskPrice(date,time)
    call_SP = math.ceil(MUCAP)
    put_SP = int(MUCAP)
    
    if printCount < 10:
        print("date={}, time={}, MUCAP={}, call_SP={}, put_SP={}".format(date,time,MUCAP,call_SP,put_SP))
        printCount += 1
# Out:
# date=20200103, time=9:45:00 AM, MUCAP=322.95, call_SP=323, put_SP=322
# date=20200106, time=9:45:00 AM, MUCAP=321.41, call_SP=322, put_SP=321
# date=20200108, time=9:45:00 AM, MUCAP=323.55, call_SP=324, put_SP=323
# date=20200110, time=9:45:00 AM, MUCAP=326.77, call_SP=327, put_SP=326
# date=20200113, time=9:45:00 AM, MUCAP=326.56, call_SP=327, put_SP=326
# date=20200115, time=9:45:00 AM, MUCAP=328.15, call_SP=329, put_SP=328
# date=20200117, time=9:45:00 AM, MUCAP=331.43, call_SP=332, put_SP=331
# date=20200121, time=9:45:00 AM, MUCAP=331.16, call_SP=332, put_SP=331
# date=20200122, time=9:45:00 AM, MUCAP=332.74, call_SP=333, put_SP=332
# date=20200124, time=9:45:00 AM, MUCAP=332.18, call_SP=333, put_SP=332

# %%
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.min_rows', 1000)

pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 200)

#print(df1.loc[df['Date']==20200309])
pd.get_option('display.max_rows')
# Out:
# 1000

# %%
def dateTimeToOpenTradePrice(date:int,time:str,callPut:str,strike:int) -> int:
    #rows = df1.loc[(df1['Date'] == date) & (df1['TimeBarStart'] == time) & (df1['CallPut'] == callPut) & (df1['Strike'] == strike)]
    #print("rows: {}".format(rows))
    OpenTradePrice = rows['OpenTradePrice']
    if OpenTradePrice.empty:
        return -1
    return OpenTradePrice

# %% [markdown]
# # This finds the OpenTradePrice of the put strike at given date and time

# %%
#df2=dataframe with just time="9:45:00 AM" and constant CallPut="P"
time, callPut = "9:45:00 AM", "P"
df2 = df.loc[(df['TimeBarStart'] == time) & (df['CallPut'] == callPut)]

#takes in rowIndex & Date & Time, outputs Max Under Close Ask Price & lastIndex for date
def dateTimeToMaxUnderCloseAskPrice(startIndex:int,date:int,time:str) -> (int,int):
    rows = df2.loc[(df2['Date'] == date) & (df2['TimeBarStart'] == time)]
    #print("rows: {}".format(rows))
    if rows['UnderCloseAskPrice'].empty:
        return (-1,startIndex)
    maxUnderCloseAskPrice = max(rows['UnderCloseAskPrice'])
    lastIndex = startIndex + len(rows) - 1
    
    #print(maxUnderCloseAskPrice)
    return (maxUnderCloseAskPrice,lastIndex)

#constant: time="9:45:00 AM" and constant CallPut="P"
#varaibles: date,strikePrice
#output: openTradePrice

printCount = 0
dateTimeMapToMUCAP = {} #map[(date,time)] = MUCAP
df2Len = len(df2)
index = 0
#for index, row in df2.iterrows():
while index < df2Len:
    row = df2.iloc[index]
    #print('row: {}'.format(row))
    if row['TimeBarStart']==time and row['CallPut']==callPut:
        date, strike = row['Date'], row['Strike']
        
        #get MUCAP price to round for call/put prices
        MUCAP,lastIndex = dateTimeToMaxUnderCloseAskPrice(index,date,time)
        dateTimeMapToMUCAP[(date,time)] = MUCAP
            
        call_SP = math.ceil(MUCAP)
        put_SP = int(MUCAP)
        
        #get openTradePrice for the put_SP we calculated
        #openTradePrice = dateTimeToOpenTradePrice(date,time,callPut,put_SP)
        #openTradePrice = df2.query('(Date==date) & (TimeBarStart==time) & (Strike==call_SP)')
        #openTradePrice = df.loc[(df2['TimeBarStart'] == time) & (df2['CallPut'] == callPut)]
        openTradePriceDF_put = df2.loc[ (df2['TimeBarStart'] == time) & (df2['CallPut'] == callPut) & (df2['Date']== date) & (df2['Strike']==put_SP)]
        openTradePrice_put = openTradePriceDF_put.iloc[0]['OpenTradePrice']
        
        index = lastIndex + 1
        
        if printCount < 10:
            print("index={},date={}, time={}, callPut={}, put_SP={}, OTP_put={}".format(index,date,time,callPut,put_SP,openTradePrice_put))
            printCount += 1
        """
        #inefficient - itereate through df again
        for index, row in df2.iterrows():        
            openTradePrice = dateTimeToOpenTradePrice(date,time,callPut,put_SP)
            if printCount < 10: 
                #print("date={}, time={}, callPut={}, put_SP={}, OTP={}".format(date,time,callPut,put_SP,openTradePrice))
                printCount += 1
        """
# Out:
# index=22,date=20200103, time=9:45:00 AM, callPut=P, put_SP=322, OTP_put=0.4
# index=34,date=20200106, time=9:45:00 AM, callPut=P, put_SP=321, OTP_put=0.52
# index=46,date=20200108, time=9:45:00 AM, callPut=P, put_SP=323, OTP_put=0.45
# index=64,date=20200110, time=9:45:00 AM, callPut=P, put_SP=326, OTP_put=0.24
# index=79,date=20200113, time=9:45:00 AM, callPut=P, put_SP=326, OTP_put=0.29
# index=93,date=20200115, time=9:45:00 AM, callPut=P, put_SP=328, OTP_put=0.5
# index=110,date=20200117, time=9:45:00 AM, callPut=P, put_SP=331, OTP_put=0.32
# index=120,date=20200121, time=9:45:00 AM, callPut=P, put_SP=331, OTP_put=0.43
# index=130,date=20200122, time=9:45:00 AM, callPut=P, put_SP=332, OTP_put=0.2
# index=144,date=20200124, time=9:45:00 AM, callPut=P, put_SP=332, OTP_put=0.38

# %%
#fucntion for rounding up - https://kodify.net/python/math/round-decimals/
def round_decimals_up(number:float, decimals:int=2):
    """
    Returns a value rounded up to a specific number of decimal places.
    """
    if not isinstance(decimals, int):
        raise TypeError("decimal places must be an integer")
    elif decimals < 0:
        raise ValueError("decimal places has to be 0 or more")
    elif decimals == 0:
        return math.ceil(number)

    factor = 10 ** decimals
    return math.ceil(number * factor) / factor
round_decimals_up(15.223,2)
# Out:
# 15.23

# %%
#constant: time="9:45:00 AM"
#varaibles: date,callput,strikePrice,
#output: openTradePriceSum (call and put together)

#df3=dataframe with just time="9:45:00 AM"
time = "9:45:00 AM"
df3 = df.loc[df['TimeBarStart'] == time]

#takes in rowIndex & Date & Time, outputs Max Under Close Ask Price & lastIndex for date
def dateTimeToMaxUnderCloseAskPrice(startIndex:int,date:int,time:str) -> (int,int):
    rows = df3.loc[(df3['Date'] == date) & (df3['TimeBarStart'] == time)] #note- can be optimized by breaking when the date/time changes
    #print("rows: {}".format(rows))
    if rows['UnderCloseAskPrice'].empty:
        return (-1,startIndex)
    maxUnderCloseAskPrice = max(rows['UnderCloseAskPrice'])
    lastIndex = startIndex + len(rows) - 1
    
    #print(maxUnderCloseAskPrice)
    return (maxUnderCloseAskPrice,lastIndex)

printCount = 0
dateTimeMapToMUCAP = {} #map[(date,time)] = MUCAP
df3Len = len(df3)
index = 0
while index < df3Len:
    row = df3.iloc[index]
    #print('row: {}'.format(row))
    startIndex = index
    
    date, strike = row['Date'], row['Strike']

    #get MUCAP price to round for call/put prices
    MUCAP,lastIndex = dateTimeToMaxUnderCloseAskPrice(index,date,time)
    dateTimeMapToMUCAP[(date,time)] = MUCAP

    put_SP = int(MUCAP)
    call_SP = math.ceil(MUCAP)

    #get openTradePrice for the put_SP we calculated
    callPut = "P"
    openTradePriceDF_put = df3.loc[ (df3['TimeBarStart'] == time) & (df3['CallPut'] == callPut) & (df3['Date']== date) & (df3['Strike']==put_SP)]
    openTradePrice_put = openTradePriceDF_put.iloc[0]['OpenTradePrice']
    #get openTradePrice for the call_SP we calculated
    callPut = "C"
    openTradePriceDF_call = df3.loc[ (df3['TimeBarStart'] == time) & (df3['CallPut'] == callPut) & (df3['Date']== date) & (df3['Strike']==call_SP)]
    openTradePrice_call = openTradePriceDF_call.iloc[0]['OpenTradePrice']
        
    sumCallPut = openTradePrice_put + openTradePrice_call
    if printCount <10:
        print("index={},date={}, time={}, put_SP={},call_SP={}, callPrice={}, putPrice={}, sumCallPut={}".format(index,date,time,put_SP,call_SP,openTradePrice_call,openTradePrice_put,round_decimals_up(sumCallPut,2)))
        printCount += 1
    
    index = lastIndex + 1
# Out:
# index=0,date=20200103, time=9:45:00 AM, put_SP=322,call_SP=323, callPrice=0.61, putPrice=0.4, sumCallPut=1.01
# index=37,date=20200106, time=9:45:00 AM, put_SP=321,call_SP=322, callPrice=0.34, putPrice=0.52, sumCallPut=0.87
# index=57,date=20200108, time=9:45:00 AM, put_SP=323,call_SP=324, callPrice=0.41, putPrice=0.45, sumCallPut=0.86
# index=78,date=20200110, time=9:45:00 AM, put_SP=326,call_SP=327, callPrice=0.39, putPrice=0.24, sumCallPut=0.63
# index=114,date=20200113, time=9:45:00 AM, put_SP=326,call_SP=327, callPrice=0.26, putPrice=0.29, sumCallPut=0.56
# index=139,date=20200115, time=9:45:00 AM, put_SP=328,call_SP=329, callPrice=0.19, putPrice=0.5, sumCallPut=0.69
# index=167,date=20200117, time=9:45:00 AM, put_SP=331,call_SP=332, callPrice=0.23, putPrice=0.32, sumCallPut=0.56
# index=200,date=20200121, time=9:45:00 AM, put_SP=331,call_SP=332, callPrice=0.15, putPrice=0.43, sumCallPut=0.58
# index=220,date=20200122, time=9:45:00 AM, put_SP=332,call_SP=333, callPrice=0.29, putPrice=0.2, sumCallPut=0.49
# index=240,date=20200124, time=9:45:00 AM, put_SP=332,call_SP=333, callPrice=0.15, putPrice=0.38, sumCallPut=0.53

# %% [markdown]
# ## Creating Dataframe with ['Date','TimeBarStart','CallPut','Strike', 'HighTradePrice']

# %%
df4 = df[['Date','TimeBarStart','CallPut','Strike', 'HighTradePrice']]
#print("df4: {}".format(df4))

# %%
#NOTE DELETING ROW IS TOO SLOW (O(N)) PER DELETE, SO WE SHOULD JUST COPY ROWS THAT WORK
"""
#9:30am - 5pm (Our initial data)
#9:46AM - 3:59PM (The time frame we want)

prevTime = None
printCounter = 0
for index, row in df4.iterrows():
    #if printCounter > 38500:
    #    print("index: {}".format(index))
    if printCounter % 1000 == 0:
        print("index: {}".format(index))
        #print("row: {}".format(row))
    printCounter += 1
    if row['TimeBarStart'][-2:] == "AM":
        if row['TimeBarStart'][0] == "9":
            #drop <= 9:45:00 AM
            if int(row['TimeBarStart'][2:4]) <= 45:
                df4.drop(index,inplace=True)
                continue
    elif row['TimeBarStart'][-2:] == "PM":
        #drop >= 4:00:00 PM
        if row['TimeBarStart'][0] == "4": #or row['TimeBarStart'][0] == "5":
            #print(index)
            df4.drop(index,inplace=True)
            continue
    #else:
    #    #missing time, use previous time
    #    row['TimeBarStart'] = prevTime
    
    prevTime = row['TimeBarStart']
"""
# Out:
# '\n#9:30am - 5pm (Our initial data)\n#9:46AM - 3:59PM (The time frame we want)\n\nprevTime = None\nprintCounter = 0\nfor index, row in df4.iterrows():\n    #if printCounter > 38500:\n    #    print("index: {}".format(index))\n    if printCounter % 1000 == 0:\n        print("index: {}".format(index))\n        #print("row: {}".format(row))\n    printCounter += 1\n    if row[\'TimeBarStart\'][-2:] == "AM":\n        if row[\'TimeBarStart\'][0] == "9":\n            #drop <= 9:45:00 AM\n            if int(row[\'TimeBarStart\'][2:4]) <= 45:\n                df4.drop(index,inplace=True)\n                continue\n    elif row[\'TimeBarStart\'][-2:] == "PM":\n        #drop >= 4:00:00 PM\n        if row[\'TimeBarStart\'][0] == "4": #or row[\'TimeBarStart\'][0] == "5":\n            #print(index)\n            df4.drop(index,inplace=True)\n            continue\n    #else:\n    #    #missing time, use previous time\n    #    row[\'TimeBarStart\'] = prevTime\n    \n    prevTime = row[\'TimeBarStart\']\n'

# %%
#THIS IS SLOW TOO BECAUSE APPENDING TO DATAFRAME IS O(N) PER OPERATION, USE LIST AND THEN CONVERT TO DATAFRAME
"""
#9:30am - 5pm (Our initial data)
#9:46AM - 3:59PM (The time frame we want)

#create an adjusted df4 that stores only 9:46AM - 3:59PM
df4Adjusted = df4.iloc[0]
df4Adjusted = df4Adjusted[0:0] #delete first row to make it empty df
#df4Adjusted = ['Date','TimeBarStart','CallPut','Strike', 'HighTradePrice']
print("df4Adjusted at start: {}".format(df4Adjusted))
print("type(df4Adjusted):{}".format(type(df4Adjusted)))
printCounter = 0
#rowsList = [] #optimization (append to list and then concat is faster than appending row by row)
for index, row in df4.iterrows():
    if printCounter % 1000 == 0:
        print("index: {}".format(index))
        #print("row: {}".format(row))
        #print("row: {}".format(row))
    printCounter += 1

    if row['TimeBarStart'][-2:] == "AM":
        if row['TimeBarStart'][0] == "9":
            if int(row['TimeBarStart'][2:4]) <= 45:
                #drop <= 9:45:00 AM
                continue
    elif row['TimeBarStart'][-2:] == "PM":
        
        if row['TimeBarStart'][0] == "4": #or row['TimeBarStart'][0] == "5":
            #drop >= 4:00:00 PM
            continue
    else:
        #missing time, use previous time
        row['TimeBarStart'] = prevTime
    
    row = pd.DataFrame(row, columns=['Date','TimeBarStart','CallPut','Strike', 'HighTradePrice'])
    df4Adjusted.append(row)
    #df4Adjusted = df4Adjusted.append(row)
    #df4Adjusted.append(pd.DataFrame(row))
    #df4Adjusted.append(df4.iloc[index])
    #rowsList.append(df4[index])
    #print("appending: {}".format(row))
    #print("____________________________________")
    #print("df4Adjusted: {}".format(df4Adjusted))
    
    prevTime = row['TimeBarStart']

print(type(df4.iloc[0]))
print(type(df4))
print(type(df4Adjusted))
"""
# Out:
# '\n#9:30am - 5pm (Our initial data)\n#9:46AM - 3:59PM (The time frame we want)\n\n#create an adjusted df4 that stores only 9:46AM - 3:59PM\ndf4Adjusted = df4.iloc[0]\ndf4Adjusted = df4Adjusted[0:0] #delete first row to make it empty df\n#df4Adjusted = [\'Date\',\'TimeBarStart\',\'CallPut\',\'Strike\', \'HighTradePrice\']\nprint("df4Adjusted at start: {}".format(df4Adjusted))\nprint("type(df4Adjusted):{}".format(type(df4Adjusted)))\nprintCounter = 0\n#rowsList = [] #optimization (append to list and then concat is faster than appending row by row)\nfor index, row in df4.iterrows():\n    if printCounter % 1000 == 0:\n        print("index: {}".format(index))\n        #print("row: {}".format(row))\n        #print("row: {}".format(row))\n    printCounter += 1\n\n    if row[\'TimeBarStart\'][-2:] == "AM":\n        if row[\'TimeBarStart\'][0] == "9":\n            if int(row[\'TimeBarStart\'][2:4]) <= 45:\n                #drop <= 9:45:00 AM\n                continue\n    elif row[\'TimeBarStart\'][-2:] == "PM":\n        \n        if row[\'TimeBarStart\'][0] == "4": #or row[\'TimeBarStart\'][0] == "5":\n            #drop >= 4:00:00 PM\n            continue\n    else:\n        #missing time, use previous time\n        row[\'TimeBarStart\'] = prevTime\n    \n    row = pd.DataFrame(row, columns=[\'Date\',\'TimeBarStart\',\'CallPut\',\'Strike\', \'HighTradePrice\'])\n    df4Adjusted.append(row)\n    #df4Adjusted = df4Adjusted.append(row)\n    #df4Adjusted.append(pd.DataFrame(row))\n    #df4Adjusted.append(df4.iloc[index])\n    #rowsList.append(df4[index])\n    #print("appending: {}".format(row))\n    #print("____________________________________")\n    #print("df4Adjusted: {}".format(df4Adjusted))\n    \n    prevTime = row[\'TimeBarStart\']\n'

# %%
#9:30am - 5pm (Our initial data)
#9:46AM - 3:59PM (The time frame we want)

#create an adjusted df4 that stores only 9:46AM - 3:59PM
df4AdjustedList = []
printCounter = 0
#rowsList = [] #optimization (append to list and then concat is faster than appending row by row)
for index, row in df4.iterrows():
    if printCounter % 100000 == 0:
        print("index: {}".format(index))
        #print("row: {}".format(row))
        #print("row: {}".format(row))
    printCounter += 1

    if row['TimeBarStart'][-2:] == "AM":
        if row['TimeBarStart'][0] == "9":
            if int(row['TimeBarStart'][2:4]) <= 45:
                #drop <= 9:45:00 AM
                continue
    elif row['TimeBarStart'][-2:] == "PM":
        
        if row['TimeBarStart'][0] == "4": #or row['TimeBarStart'][0] == "5":
            #drop >= 4:00:00 PM
            continue
    else:
        #missing time, use previous time
        row['TimeBarStart'] = prevTime
    
    #row = pd.DataFrame(row, columns=['Date','TimeBarStart','CallPut','Strike', 'HighTradePrice'])
    #df4Adjusted.append(row)
    df4AdjustedList.append(list(row))
    #df4Adjusted = df4Adjusted.append(row)
    #df4Adjusted.append(pd.DataFrame(row))
